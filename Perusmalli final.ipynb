# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisesti sosiaaliturvaa eri tiloissa.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %% [markdown]
# Then load all modules and set parameters for simulations.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.15 valittaa paljon)
# ei taida toimia piilottaminen
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Populating the interactive namespace from numpy and matplotlib

# %%
# parameters for the simulation
# episode = 51 / 205 timesteps (1y/3m timestep)
pop_size=20_000 # size of the population to be simulated
size1=20_000_000 #0_000 # number of timesteps in phase 1 training (callback not used)
size2=100_000_000 #0_000 # number of timesteps in phase 2 training (callback is used to save the best results)
size3=20_000_000 # number of timesteps in phase 1 training (callback not used) for policy changes
batch1=1_00 # size of minibatch in phase 1 as number of episodes
batch2=9_00  # size of minibatch in phase 1 as number of episodes
callback_minsteps=batch2 # how many episodes callback needs 
deterministic=False # use deterministic prediction (True) or probabilitic prediction (False)
mortality=False # include mortality in computations
randomness=True # include externally given, random state-transitions (parental leaves, disability, lay-offs) 
pinkslip=True # include lay-offs at 5 percent level each year
rlmodel='acktr' # use ACKTR algorithm
twostage=False # ajataan kahdessa vaiheessa vai ei
perusmalli='best/malli_perus3'
perusresults='results/perus_results3'

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
cc1=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=False)
cc1.explain()
cc1.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,
                save=perusmalli,plot=True,cont=True,start_from=perusmalli,results=perusresults,
                callback_minsteps=callback_minsteps,rlmodel=rlmodel,twostage=twostage)
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 63.5
# max_retirementage 68.5
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# include_putki None
# include_pinkslip True
# step 0.25
#
# train...
# phase 1
# batch 9 learning rate 0.125 scaled 0.375
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:57: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/policies.py:562: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/distributions.py:323: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/distributions.py:324: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:158: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:163: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:178: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:97: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:293: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:541: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:543: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:203: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:205: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# training...
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1035: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:287: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:288: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:968: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:909: The name tf.mod is deprecated. Please use tf.math.mod instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:616: The name tf.self_adjoint_eig is deprecated. Please use tf.linalg.eigh instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:300: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:581: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 2651     |
# | nupdates           | 1        |
# | policy_entropy     | 0.87     |
# | policy_loss        | 0.413    |
# | total_timesteps    | 0        |
# | value_loss         | 0.743    |
# ---------------------------------
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:251: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:252: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# ---------------------------------
# | explained_variance | 0.867    |
# | fps                | 2859     |
# | nupdates           | 10       |
# | policy_entropy     | 0.809    |
# | policy_loss        | -1.15    |
# | total_timesteps    | 196353   |
# | value_loss         | 4.21     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.858    |
# | fps                | 2804     |
# | nupdates           | 20       |
# | policy_entropy     | 0.849    |
# | policy_loss        | 4.3      |
# | total_timesteps    | 414523   |
# | value_loss         | 30.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.931    |
# | fps                | 2791     |
# | nupdates           | 30       |
# | policy_entropy     | 0.827    |
# | policy_loss        | 1.35     |
# | total_timesteps    | 632693   |
# | value_loss         | 3.97     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 2778     |
# | nupdates           | 40       |
# | policy_entropy     | 0.82     |
# | policy_loss        | -1.9     |
# | total_timesteps    | 850863   |
# | value_loss         | 6.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.938    |
# | fps                | 2772     |
# | nupdates           | 50       |
# | policy_entropy     | 0.847    |
# | policy_loss        | -1.48    |
# | total_timesteps    | 1069033  |
# | value_loss         | 4.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 2769     |
# | nupdates           | 60       |
# | policy_entropy     | 0.814    |
# | policy_loss        | 0.915    |
# | total_timesteps    | 1287203  |
# | value_loss         | 2.07     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 2768     |
# | nupdates           | 70       |
# | policy_entropy     | 0.821    |
# | policy_loss        | 0.847    |
# | total_timesteps    | 1505373  |
# | value_loss         | 1.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 2767     |
# | nupdates           | 80       |
# | policy_entropy     | 0.837    |
# | policy_loss        | -0.767   |
# | total_timesteps    | 1723543  |
# | value_loss         | 1.5      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2765     |
# | nupdates           | 90       |
# | policy_entropy     | 0.833    |
# | policy_loss        | -0.119   |
# | total_timesteps    | 1941713  |
# | value_loss         | 0.481    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2764     |
# | nupdates           | 100      |
# | policy_entropy     | 0.842    |
# | policy_loss        | 0.379    |
# | total_timesteps    | 2159883  |
# | value_loss         | 0.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 2766     |
# | nupdates           | 110      |
# | policy_entropy     | 0.855    |
# | policy_loss        | -0.375   |
# | total_timesteps    | 2378053  |
# | value_loss         | 0.749    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2769     |
# | nupdates           | 120      |
# | policy_entropy     | 0.866    |
# | policy_loss        | 0.0795   |
# | total_timesteps    | 2596223  |
# | value_loss         | 0.396    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2772     |
# | nupdates           | 130      |
# | policy_entropy     | 0.846    |
# | policy_loss        | -0.0402  |
# | total_timesteps    | 2814393  |
# | value_loss         | 0.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.976    |
# | fps                | 2774     |
# | nupdates           | 140      |
# | policy_entropy     | 0.851    |
# | policy_loss        | 0.0329   |
# | total_timesteps    | 3032563  |
# | value_loss         | 0.341    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 2777     |
# | nupdates           | 150      |
# | policy_entropy     | 0.881    |
# | policy_loss        | 0.0168   |
# | total_timesteps    | 3250733  |
# | value_loss         | 0.298    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 2778     |
# | nupdates           | 160      |
# | policy_entropy     | 0.88     |
# | policy_loss        | -0.0388  |
# | total_timesteps    | 3468903  |
# | value_loss         | 0.401    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2776     |
# | nupdates           | 170      |
# | policy_entropy     | 0.874    |
# | policy_loss        | 0.0185   |
# | total_timesteps    | 3687073  |
# | value_loss         | 0.347    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.976    |
# | fps                | 2771     |
# | nupdates           | 180      |
# | policy_entropy     | 0.841    |
# | policy_loss        | -0.00169 |
# | total_timesteps    | 3905243  |
# | value_loss         | 0.355    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 2770     |
# | nupdates           | 190      |
# | policy_entropy     | 0.886    |
# | policy_loss        | 0.0132   |
# | total_timesteps    | 4123413  |
# | value_loss         | 0.333    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2770     |
# | nupdates           | 200      |
# | policy_entropy     | 0.888    |
# | policy_loss        | -0.0329  |
# | total_timesteps    | 4341583  |
# | value_loss         | 0.36     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 2770     |
# | nupdates           | 210      |
# | policy_entropy     | 0.888    |
# | policy_loss        | -0.00362 |
# | total_timesteps    | 4559753  |
# | value_loss         | 0.361    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2770     |
# | nupdates           | 220      |
# | policy_entropy     | 0.866    |
# | policy_loss        | -0.0379  |
# | total_timesteps    | 4777923  |
# | value_loss         | 0.351    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 2771     |
# | nupdates           | 230      |
# | policy_entropy     | 0.878    |
# | policy_loss        | -0.0209  |
# | total_timesteps    | 4996093  |
# | value_loss         | 0.328    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 2772     |
# | nupdates           | 240      |
# | policy_entropy     | 0.863    |
# | policy_loss        | 0.0589   |
# | total_timesteps    | 5214263  |
# | value_loss         | 0.351    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 2769     |
# | nupdates           | 250      |
# | policy_entropy     | 0.828    |
# | policy_loss        | 0.0562   |
# | total_timesteps    | 5432433  |
# | value_loss         | 0.316    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 2770     |
# | nupdates           | 260      |
# | policy_entropy     | 0.868    |
# | policy_loss        | -0.0204  |
# | total_timesteps    | 5650603  |
# | value_loss         | 0.366    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2770     |
# | nupdates           | 270      |
# | policy_entropy     | 0.87     |
# | policy_loss        | 0.00619  |
# | total_timesteps    | 5868773  |
# | value_loss         | 0.362    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.976    |
# | fps                | 2772     |
# | nupdates           | 280      |
# | policy_entropy     | 0.849    |
# | policy_loss        | 0.0411   |
# | total_timesteps    | 6086943  |
# | value_loss         | 0.383    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 2773     |
# | nupdates           | 290      |
# | policy_entropy     | 0.866    |
# | policy_loss        | 0.0314   |
# | total_timesteps    | 6305113  |
# | value_loss         | 0.291    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 2774     |
# | nupdates           | 300      |
# | policy_entropy     | 0.858    |
# | policy_loss        | -0.0055  |
# | total_timesteps    | 6523283  |
# | value_loss         | 0.408    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2774     |
# | nupdates           | 310      |
# | policy_entropy     | 0.875    |
# | policy_loss        | -0.0186  |
# | total_timesteps    | 6741453  |
# | value_loss         | 0.412    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.973    |
# | fps                | 2775     |
# | nupdates           | 320      |
# | policy_entropy     | 0.858    |
# | policy_loss        | -0.00628 |
# | total_timesteps    | 6959623  |
# | value_loss         | 0.397    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2776     |
# | nupdates           | 330      |
# | policy_entropy     | 0.868    |
# | policy_loss        | -0.0129  |
# | total_timesteps    | 7177793  |
# | value_loss         | 0.358    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.973    |
# | fps                | 2777     |
# | nupdates           | 340      |
# | policy_entropy     | 0.881    |
# | policy_loss        | -0.00589 |
# | total_timesteps    | 7395963  |
# | value_loss         | 0.369    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2777     |
# | nupdates           | 350      |
# | policy_entropy     | 0.874    |
# | policy_loss        | -0.0175  |
# | total_timesteps    | 7614133  |
# | value_loss         | 0.377    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 2778     |
# | nupdates           | 360      |
# | policy_entropy     | 0.866    |
# | policy_loss        | 0.000933 |
# | total_timesteps    | 7832303  |
# | value_loss         | 0.323    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 2777     |
# | nupdates           | 370      |
# | policy_entropy     | 0.869    |
# | policy_loss        | 0.00819  |
# | total_timesteps    | 8050473  |
# | value_loss         | 0.342    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2776     |
# | nupdates           | 380      |
# | policy_entropy     | 0.881    |
# | policy_loss        | -0.0429  |
# | total_timesteps    | 8268643  |
# | value_loss         | 0.403    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2776     |
# | nupdates           | 390      |
# | policy_entropy     | 0.875    |
# | policy_loss        | -0.0421  |
# | total_timesteps    | 8486813  |
# | value_loss         | 0.352    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 2776     |
# | nupdates           | 400      |
# | policy_entropy     | 0.898    |
# | policy_loss        | -0.0572  |
# | total_timesteps    | 8704983  |
# | value_loss         | 0.508    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.973    |
# | fps                | 2775     |
# | nupdates           | 410      |
# | policy_entropy     | 0.882    |
# | policy_loss        | 0.00594  |
# | total_timesteps    | 8923153  |
# | value_loss         | 0.397    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 2775     |
# | nupdates           | 420      |
# | policy_entropy     | 0.88     |
# | policy_loss        | -0.00784 |
# | total_timesteps    | 9141323  |
# | value_loss         | 0.346    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 2775     |
# | nupdates           | 430      |
# | policy_entropy     | 0.87     |
# | policy_loss        | -0.0193  |
# | total_timesteps    | 9359493  |
# | value_loss         | 0.388    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 2775     |
# | nupdates           | 440      |
# | policy_entropy     | 0.866    |
# | policy_loss        | 0.0198   |
# | total_timesteps    | 9577663  |
# | value_loss         | 0.299    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 2775     |
# | nupdates           | 450      |
# | policy_entropy     | 0.859    |
# | policy_loss        | -0.0493  |
# | total_timesteps    | 9795833  |
# | value_loss         | 0.442    |
# ---------------------------------
# done
# acktr
# simulating  best/malli_perus3
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=10000), HTML(value='')))
# No handles with labels found to put in legend.
# Yhteensä reward 239.83606623522985

# %%
cc1b=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=False)
cc1b.render(load=perusresults)
# Out:
# No mortality included
# No handles with labels found to put in legend.
# Yhteensä reward 239.83606623522985

# %% [markdown]
# # Deep Q-network
#
# Kokeillaan toista menetelmää ratkaisuun. Muutos on helppo tehdä, muutetaan vain algoritmin valintaa säätelevän parametrin _rlmodel_ arvo, ja varmistetaan että kaikki lähtee alusta liikkeelle (_cont=False_). Deep Q-network on menetelmänä hitaampi kuin ACKTR, joten tässä aika-askelten määrä on rajattu 1 000 000:aan.

# %%
cc1q=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=False)
cc1q.explain()
cc1q.run_results(debug=False,steps1=1_000_000,steps2=size2,pop=1_000,deterministic=deterministic,
                train=True,predict=True,batch1=1,batch2=batch2,
                save=perusmalli+'_dqn',plot=True,cont=False,start_from=perusmalli+'_dqn',results=perusresults+'_dqn',
                callback_minsteps=callback_minsteps,rlmodel='dqn',twostage=False)
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 63.5
# max_retirementage 68.5
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# include_putki None
# include_pinkslip True
# step 0.25
#
# train...
# phase 1
# batch 1 learning rate 0.25 scaled 0.25
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/deepq/dqn.py:122: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/deepq/build_graph.py:372: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# training...
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:187: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1000     |
# | mean 100 episode reward | 236      |
# | steps                   | 200798   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 2000     |
# | mean 100 episode reward | 237      |
# | steps                   | 401798   |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 3000     |
# | mean 100 episode reward | 237      |
# | steps                   | 602798   |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eb028eb5cbab> in <module>
#       5                 train=True,predict=True,batch1=1,batch2=batch2,
#       6                 save=perusmalli+'_dqn',plot=True,cont=False,start_from=perusmalli+'_dqn',results='results/perus_results3_dqn',
# ----> 7                 callback_minsteps=callback_minsteps,rlmodel='dqn',twostage=False)
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/lifecycle.py in run_results(self, steps1, steps2, pop, rlmodel, twostage, save, debug, simut, results, stats, deterministic, train, predict, batch1, batch2, cont, start_from, plot, callback_minsteps)
#     661                 self.run_protocol(rlmodel=rlmodel,steps1=steps1,steps2=steps2,
#     662                                  debug=debug,batch1=batch1,batch2=batch2,cont=cont,
# --> 663                                  save=save,twostage=twostage)
#     664         if predict:
#     665             #print('predict...')
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/lifecycle.py in run_protocol(self, steps1, steps2, rlmodel, debug, batch1, batch2, cont, twostage, start_from, save)
#     693             else:
#     694                 self.train(steps=steps1,cont=False,rlmodel=rlmodel,save=tmpname,batch=batch1,debug=debug,
# --> 695                            use_callback=False,use_vecmonitor=False,log_interval=1000,verbose=1)
#     696
#     697         if twostage and steps2>0:
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/lifecycle.py in train(self, train, debug, steps, cont, rlmodel, save, pop, batch, max_grad_norm, learning_rate, start_from, max_n_cpu, plot, use_vecmonitor, bestname, use_callback, log_interval, verbose)
#     442             model.learn(total_timesteps=steps, callback=self.callback,log_interval=log_interval)
#     443         else:
# --> 444             model.learn(total_timesteps=steps, log_interval=log_interval)
#     445
#     446         model.save(save)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/deepq/dqn.py in learn(self, total_timesteps, callback, seed, log_interval, tb_log_name, reset_num_timesteps, replay_wrapper)
#     218                     ep_done = np.array([done]).reshape((1, -1))
#     219                     self.episode_reward = total_episode_reward_logger(self.episode_reward, ep_rew, ep_done, writer,
# --> 220                                                                       self.num_timesteps)
#     221
#     222                 episode_rewards[-1] += rew
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/a2c/utils.py in total_episode_reward_logger(rew_acc, rewards, masks, writer, steps)
#     585                     summary = tf.Summary(value=[tf.Summary.Value(tag="episode_reward", simple_value=rew_acc[env_idx])])
#     586                     writer.add_summary(summary, steps + dones_idx[k, 0])
# --> 587                 rew_acc[env_idx] = sum(rewards[env_idx, dones_idx[-1, 0]:])
#     588
#     589     return rew_acc
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in __exit__(self, type_arg, value_arg, traceback_arg)
#    2359         if self._in_graph_mode and not self._building_function:
#    2360           self._graph_context_manager.__exit__(type_arg, value_arg,
# -> 2361                                                traceback_arg)
#    2362
#    2363
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in get_controller(self, default)
#    5478       with super(_DefaultGraphStack,
#    5479                  self).get_controller(default) as g, context.graph_mode():
# -> 5480         yield g
#    5481     finally:
#    5482       # If an exception is raised here it may be hiding a related exception in
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# KeyboardInterrupt:
