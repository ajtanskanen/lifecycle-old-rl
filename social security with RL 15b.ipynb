# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisempi työttömyysturvamalli.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %% [markdown]
# Then load all modules.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.5 valittaa paljon)
import warnings
warnings.filterwarnings('ignore')

# parameters for the simulation
# episode = 51 / 205 timesteps (1y/3m timestep)
pop_size=10_000 # size of the population to be simulated
size1=50_000_000 # number of timesteps in phase 1 training (callback not used)
size2=50_000_000 # number of timesteps in phase 2 training (callback is used to save the best results)
batch1=1 # size of minibatch in phase 1 as number of episodes
batch2=5_000  # size of minibatch in phase 1 as number of episodes
callback_minsteps=batch2 # how many episodes callback needs 
deterministic=True # use deterministic prediction (True) or probabilitic prediction (False)
mortality=False # include mortality in computations
randomness=True # include randomness in the state transitions (e.g., maternity leave)

# Yhteensä reward 220.8344309056833 non-det
#
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
cc1=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              deterministic=deterministic,randomness=randomness)
cc1.explain()
cc1.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=False,predict=True,batch1=batch1,batch2=batch2,save='best/malli_perus',
                plot=True,cont=False,start_from='best/malli_perus',results='results/perus_results',
                callback_minsteps=callback_minsteps)
cc1.render(load='results/perus_results')
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 65
# max_retirementage 70
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# deterministic True
#
# include_putki None
# step 0.25
#
# predict...
# simulating  best/malli_perus
# predicting...
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:57: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:562: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/distributions.py:323: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/distributions.py:324: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:158: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:163: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:97: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:293: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:541: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:543: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:203: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /Users/antti/miniconda3/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:205: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# HBox(children=(IntProgress(value=0, description='Population', max=10000, style=ProgressStyle(description_width…
# No handles with labels found to put in legend.
# Yhteensä reward 222.15196845644368

# %% [markdown]
# # Porrastettu työttömyysturva

# %%
cc2_porras=Lifecycle(env='unemploymentSteps-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness)
cc2_porras.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_steps',plot=True,
                results='results/steps_results',start_from='best/malli_steps',
                callback_minsteps=callback_minsteps)
cc2_porras.render(load='results/steps_results')
# Out:
# No mortality included
# train...
# phase 1
# training...
# ---------------------------------
# | explained_variance | 0.00315  |
# | fps                | 1819     |
# | nupdates           | 1        |
# | policy_entropy     | 1.39     |
# | policy_loss        | 55.2     |
# | total_timesteps    | 0        |
# | value_loss         | 1.67e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.895    |
# | fps                | 2296     |
# | nupdates           | 1000     |
# | policy_entropy     | 1.06     |
# | policy_loss        | -0.485   |
# | total_timesteps    | 2458539  |
# | value_loss         | 7.77     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 2307     |
# | nupdates           | 2000     |
# | policy_entropy     | 0.813    |
# | policy_loss        | 0.0726   |
# | total_timesteps    | 4919539  |
# | value_loss         | 7.09     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.894    |
# | fps                | 2314     |
# | nupdates           | 3000     |
# | policy_entropy     | 0.769    |
# | policy_loss        | 0.199    |
# | total_timesteps    | 7380539  |
# | value_loss         | 3.78     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 2319     |
# | nupdates           | 4000     |
# | policy_entropy     | 0.484    |
# | policy_loss        | 0.271    |
# | total_timesteps    | 9841539  |
# | value_loss         | 2.63     |
# ---------------------------------
# done
# phase 2
# init vecmonitor:  tmp/monitor.csv
# training...
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.76122 |
# | explained_variance | 0.845     |
# | fps                | 3071      |
# | nupdates           | 1         |
# | policy_entropy     | 0.482     |
# | policy_loss        | -0.0739   |
# | total_timesteps    | 0         |
# | value_loss         | 12.7      |
# ----------------------------------
# 2050200 timesteps 10200 episodes
# New best mean reward: 220.28 - Last best reward per episode: -inf
# saved as  best/malli_steps
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.12593 |
# | explained_variance | 0.791     |
# | fps                | 3131      |
# | nupdates           | 2         |
# | policy_entropy     | 0.467     |
# | policy_loss        | 3.59      |
# | total_timesteps    | 1025821   |
# | value_loss         | 87        |
# ----------------------------------
# 3075300 timesteps 15300 episodes
# New best mean reward: 220.97 - Last best reward per episode: 220.28
# saved as  best/malli_steps
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 216.86142 |
# | explained_variance | 0.784     |
# | fps                | 3164      |
# | nupdates           | 3         |
# | policy_entropy     | 0.48      |
# | policy_loss        | 3.2       |
# | total_timesteps    | 2051642   |
# | value_loss         | 71.1      |
# ----------------------------------
# 4102812 timesteps 20412 episodes
# Best mean reward: 220.97 - Last mean reward per episode: 220.62
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.10092 |
# | explained_variance | 0.825     |
# | fps                | 3160      |
# | nupdates           | 4         |
# | policy_entropy     | 0.524     |
# | policy_loss        | -0.969    |
# | total_timesteps    | 3077463   |
# | value_loss         | 16.9      |
# ----------------------------------
# 5127912 timesteps 25512 episodes
# Best mean reward: 220.97 - Last mean reward per episode: 220.63
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.42914 |
# | explained_variance | 0.847     |
# | fps                | 3177      |
# | nupdates           | 5         |
# | policy_entropy     | 0.541     |
# | policy_loss        | -1.03     |
# | total_timesteps    | 4103284   |
# | value_loss         | 15.9      |
# ----------------------------------
# 6153012 timesteps 30612 episodes
# Best mean reward: 220.97 - Last mean reward per episode: 220.22
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 219.3097 |
# | explained_variance | 0.844    |
# | fps                | 3182     |
# | nupdates           | 6        |
# | policy_entropy     | 0.537    |
# | policy_loss        | 2.53     |
# | total_timesteps    | 5129105  |
# | value_loss         | 34.9     |
# ---------------------------------
# 7180524 timesteps 35724 episodes
# Best mean reward: 220.97 - Last mean reward per episode: 220.63
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 218.9267 |
# | explained_variance | 0.83     |
# | fps                | 3194     |
# | nupdates           | 7        |
# | policy_entropy     | 0.545    |
# | policy_loss        | 2.14     |
# | total_timesteps    | 6154926  |
# | value_loss         | 27.9     |
# ---------------------------------
# 8205624 timesteps 40824 episodes
# Best mean reward: 220.97 - Last mean reward per episode: 220.80
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.69258 |
# | explained_variance | 0.805     |
# | fps                | 3198      |
# | nupdates           | 8         |
# | policy_entropy     | 0.573     |
# | policy_loss        | -1.47     |
# | total_timesteps    | 7180747   |
# | value_loss         | 24.3      |
# ----------------------------------
# 9230724 timesteps 45924 episodes
# New best mean reward: 221.09 - Last best reward per episode: 220.97
# saved as  best/malli_steps
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.47559 |
# | explained_variance | 0.829     |
# | fps                | 3204      |
# | nupdates           | 9         |
# | policy_entropy     | 0.577     |
# | policy_loss        | -1.63     |
# | total_timesteps    | 8206568   |
# | value_loss         | 23.2      |
# ----------------------------------
# 10255824 timesteps 51024 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 219.20
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 216.35542 |
# | explained_variance | 0.85      |
# | fps                | 3208      |
# | nupdates           | 10        |
# | policy_entropy     | 0.575     |
# | policy_loss        | 0.86      |
# | total_timesteps    | 9232389   |
# | value_loss         | 14.8      |
# ----------------------------------
# 11283336 timesteps 56136 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.65
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 218.1395 |
# | explained_variance | 0.843    |
# | fps                | 3209     |
# | nupdates           | 11       |
# | policy_entropy     | 0.568    |
# | policy_loss        | 0.412    |
# | total_timesteps    | 10258210 |
# | value_loss         | 13.4     |
# ---------------------------------
# 12308436 timesteps 61236 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.13
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.67586 |
# | explained_variance | 0.845     |
# | fps                | 3213      |
# | nupdates           | 12        |
# | policy_entropy     | 0.585     |
# | policy_loss        | -2.19     |
# | total_timesteps    | 11284031  |
# | value_loss         | 26.1      |
# ----------------------------------
# 13333536 timesteps 66336 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.27
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.26212 |
# | explained_variance | 0.845     |
# | fps                | 3212      |
# | nupdates           | 13        |
# | policy_entropy     | 0.586     |
# | policy_loss        | -2.2      |
# | total_timesteps    | 12309852  |
# | value_loss         | 26.1      |
# ----------------------------------
# 14361048 timesteps 71448 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.55
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.21169 |
# | explained_variance | 0.842     |
# | fps                | 3214      |
# | nupdates           | 14        |
# | policy_entropy     | 0.585     |
# | policy_loss        | -2.2      |
# | total_timesteps    | 13335673  |
# | value_loss         | 26.3      |
# ----------------------------------
# 15386148 timesteps 76548 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.36
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.69482 |
# | explained_variance | 0.851     |
# | fps                | 3214      |
# | nupdates           | 15        |
# | policy_entropy     | 0.585     |
# | policy_loss        | -2.17     |
# | total_timesteps    | 14361494  |
# | value_loss         | 25.4      |
# ----------------------------------
# 16411248 timesteps 81648 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.44
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 223.5507 |
# | explained_variance | 0.844    |
# | fps                | 3214     |
# | nupdates           | 16       |
# | policy_entropy     | 0.584    |
# | policy_loss        | -2.16    |
# | total_timesteps    | 15387315 |
# | value_loss         | 25.6     |
# ---------------------------------
# 17438760 timesteps 86760 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 219.34
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 219.8039 |
# | explained_variance | 0.849    |
# | fps                | 3216     |
# | nupdates           | 17       |
# | policy_entropy     | 0.591    |
# | policy_loss        | -2.18    |
# | total_timesteps    | 16413136 |
# | value_loss         | 25.8     |
# ---------------------------------
# 18463860 timesteps 91860 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 219.95
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 224.24004 |
# | explained_variance | 0.843     |
# | fps                | 3215      |
# | nupdates           | 18        |
# | policy_entropy     | 0.585     |
# | policy_loss        | -2.11     |
# | total_timesteps    | 17438957  |
# | value_loss         | 25.4      |
# ----------------------------------
# 19488960 timesteps 96960 episodes
# Best mean reward: 221.09 - Last mean reward per episode: 220.68
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.82884 |
# | explained_variance | 0.843     |
# | fps                | 3217      |
# | nupdates           | 19        |
# | policy_entropy     | 0.579     |
# | policy_loss        | -2.01     |
# | total_timesteps    | 18464778  |
# | value_loss         | 24.2      |
# ----------------------------------
# done
# predict...
# simulating  best/malli_steps
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=10000), HTML(value='')))
# No handles with labels found to put in legend.
# Yhteensä reward 220.78400693174427

# %%
cc2_porras.compare_with(cc1)
# Out:
# 10000.0 10000.0
# Työllisyysvaikutus 25-62-vuotiaisiin noin -67565.0 htv ja -62963.0 työllistä
# Työllisyysasteerp 25-62-vuotiailla noin -1.9740204202306135 prosenttia
# Epävarmuus työllisyysasteissa 0.0196, hajonta 0.027805149715180347

# %% [markdown]
# # Työttömyysputken poisto
#
# Työttömyysputki on suosittu elinkaarimalleissa. Tarkastellaan millainen työllisyysvaikutus on putken poistamisella.

# %%
cc1_putki=Lifecycle(env='unemployment-v1',minimal=False,include_putki=False,mortality=mortality,
                    perustulo=False,randomness=randomness)
cc1_putki.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                      train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_putki',
                      plot=True,results='results/putki_results',
                callback_minsteps=callback_minsteps)
cc1_putki.render(load='results/putki_results')
cc1_putki.compare_with(cc1)
# Out:
# No mortality included
# train...
# phase 1
# training...
# ---------------------------------
# | explained_variance | 0.0019   |
# | fps                | 1842     |
# | nupdates           | 1        |
# | policy_entropy     | 1.39     |
# | policy_loss        | 55.5     |
# | total_timesteps    | 0        |
# | value_loss         | 1.69e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.749    |
# | fps                | 2305     |
# | nupdates           | 1000     |
# | policy_entropy     | 1        |
# | policy_loss        | -0.155   |
# | total_timesteps    | 2458539  |
# | value_loss         | 13.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.85     |
# | fps                | 2318     |
# | nupdates           | 2000     |
# | policy_entropy     | 0.765    |
# | policy_loss        | -0.4     |
# | total_timesteps    | 4919539  |
# | value_loss         | 12.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.949    |
# | fps                | 2324     |
# | nupdates           | 3000     |
# | policy_entropy     | 0.531    |
# | policy_loss        | 0.2      |
# | total_timesteps    | 7380539  |
# | value_loss         | 3.65     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.848    |
# | fps                | 2319     |
# | nupdates           | 4000     |
# | policy_entropy     | 0.488    |
# | policy_loss        | -0.0288  |
# | total_timesteps    | 9841539  |
# | value_loss         | 8.43     |
# ---------------------------------
# done
# phase 2
# init vecmonitor:  tmp/monitor.csv
# training...
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.98485 |
# | explained_variance | 0.851     |
# | fps                | 3085      |
# | nupdates           | 1         |
# | policy_entropy     | 0.535     |
# | policy_loss        | -0.00968  |
# | total_timesteps    | 0         |
# | value_loss         | 12.4      |
# ----------------------------------
# 2050200 timesteps 10200 episodes
# New best mean reward: 220.11 - Last best reward per episode: -inf
# saved as  best/malli_putki
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 217.5387 |
# | explained_variance | 0.803    |
# | fps                | 3117     |
# | nupdates           | 2        |
# | policy_entropy     | 0.543    |
# | policy_loss        | -2.64    |
# | total_timesteps    | 1025821  |
# | value_loss         | 44.9     |
# ---------------------------------
# 3075300 timesteps 15300 episodes
# New best mean reward: 220.47 - Last best reward per episode: 220.11
# saved as  best/malli_putki
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.62354 |
# | explained_variance | 0.767     |
# | fps                | 3164      |
# | nupdates           | 3         |
# | policy_entropy     | 0.529     |
# | policy_loss        | -1.18     |
# | total_timesteps    | 2051642   |
# | value_loss         | 26.4      |
# ----------------------------------
# 4102812 timesteps 20412 episodes
# Best mean reward: 220.47 - Last mean reward per episode: 220.16
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.58159 |
# | explained_variance | 0.777     |
# | fps                | 3189      |
# | nupdates           | 4         |
# | policy_entropy     | 0.497     |
# | policy_loss        | 2.77      |
# | total_timesteps    | 3077463   |
# | value_loss         | 49.1      |
# ----------------------------------
# 5127912 timesteps 25512 episodes
# New best mean reward: 221.19 - Last best reward per episode: 220.47
# saved as  best/malli_putki
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 220.7844 |
# | explained_variance | 0.789    |
# | fps                | 3203     |
# | nupdates           | 5        |
# | policy_entropy     | 0.493    |
# | policy_loss        | 3.09     |
# | total_timesteps    | 4103284  |
# | value_loss         | 58.8     |
# ---------------------------------
# 6153012 timesteps 30612 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.70
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.39099 |
# | explained_variance | 0.795     |
# | fps                | 3213      |
# | nupdates           | 6         |
# | policy_entropy     | 0.51      |
# | policy_loss        | 0.659     |
# | total_timesteps    | 5129105   |
# | value_loss         | 18.7      |
# ----------------------------------
# 7180524 timesteps 35724 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.53
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 218.96027 |
# | explained_variance | 0.795     |
# | fps                | 3220      |
# | nupdates           | 7         |
# | policy_entropy     | 0.536     |
# | policy_loss        | -4.23     |
# | total_timesteps    | 6154926   |
# | value_loss         | 81.3      |
# ----------------------------------
# 8205624 timesteps 40824 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.34
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.66586 |
# | explained_variance | 0.804     |
# | fps                | 3223      |
# | nupdates           | 8         |
# | policy_entropy     | 0.555     |
# | policy_loss        | -5.85     |
# | total_timesteps    | 7180747   |
# | value_loss         | 132       |
# ----------------------------------
# 9230724 timesteps 45924 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.33
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.11635 |
# | explained_variance | 0.796     |
# | fps                | 3226      |
# | nupdates           | 9         |
# | policy_entropy     | 0.547     |
# | policy_loss        | -4.51     |
# | total_timesteps    | 8206568   |
# | value_loss         | 86.1      |
# ----------------------------------
# 10255824 timesteps 51024 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.50
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 227.02074 |
# | explained_variance | 0.803     |
# | fps                | 3227      |
# | nupdates           | 10        |
# | policy_entropy     | 0.528     |
# | policy_loss        | -1.25     |
# | total_timesteps    | 9232389   |
# | value_loss         | 21.2      |
# ----------------------------------
# 11283336 timesteps 56136 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.55
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 216.93443 |
# | explained_variance | 0.797     |
# | fps                | 3230      |
# | nupdates           | 11        |
# | policy_entropy     | 0.504     |
# | policy_loss        | 2.83      |
# | total_timesteps    | 10258210  |
# | value_loss         | 51.5      |
# ----------------------------------
# 12308436 timesteps 61236 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.94
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 224.41963 |
# | explained_variance | 0.798     |
# | fps                | 3228      |
# | nupdates           | 12        |
# | policy_entropy     | 0.493     |
# | policy_loss        | 4.35      |
# | total_timesteps    | 11284031  |
# | value_loss         | 99.6      |
# ----------------------------------
# 13333536 timesteps 66336 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.67
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.20578 |
# | explained_variance | 0.8       |
# | fps                | 3230      |
# | nupdates           | 13        |
# | policy_entropy     | 0.495     |
# | policy_loss        | 4.33      |
# | total_timesteps    | 12309852  |
# | value_loss         | 98.3      |
# ----------------------------------
# 14361048 timesteps 71448 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.43
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.37743 |
# | explained_variance | 0.799     |
# | fps                | 3230      |
# | nupdates           | 14        |
# | policy_entropy     | 0.493     |
# | policy_loss        | 4.3       |
# | total_timesteps    | 13335673  |
# | value_loss         | 97.7      |
# ----------------------------------
# 15386148 timesteps 76548 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.15
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.54205 |
# | explained_variance | 0.81      |
# | fps                | 3232      |
# | nupdates           | 15        |
# | policy_entropy     | 0.503     |
# | policy_loss        | 4.35      |
# | total_timesteps    | 14361494  |
# | value_loss         | 96.1      |
# ----------------------------------
# 16411248 timesteps 81648 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.14
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.93353 |
# | explained_variance | 0.803     |
# | fps                | 3234      |
# | nupdates           | 16        |
# | policy_entropy     | 0.501     |
# | policy_loss        | 4.28      |
# | total_timesteps    | 15387315  |
# | value_loss         | 94.9      |
# ----------------------------------
# 17438760 timesteps 86760 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.94
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.82205 |
# | explained_variance | 0.802     |
# | fps                | 3235      |
# | nupdates           | 17        |
# | policy_entropy     | 0.498     |
# | policy_loss        | 4.26      |
# | total_timesteps    | 16413136  |
# | value_loss         | 94.5      |
# ----------------------------------
# 18463860 timesteps 91860 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.05
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.22554 |
# | explained_variance | 0.808     |
# | fps                | 3232      |
# | nupdates           | 18        |
# | policy_entropy     | 0.5       |
# | policy_loss        | 4.2       |
# | total_timesteps    | 17438957  |
# | value_loss         | 92        |
# ----------------------------------
# 19488960 timesteps 96960 episodes
# Best mean reward: 221.19 - Last mean reward per episode: 220.28
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.61801 |
# | explained_variance | 0.81      |
# | fps                | 3234      |
# | nupdates           | 19        |
# | policy_entropy     | 0.5       |
# | policy_loss        | 4.16      |
# | total_timesteps    | 18464778  |
# | value_loss         | 90.9      |
# ----------------------------------
# done
# predict...
# simulating  best/malli_putki
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=10000), HTML(value='')))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e8ecc2a74975> in <module>
#       5                       plot=True,results='results/malli_results',
#       6                 callback_minsteps=callback_minsteps)
# ----> 7 cc1_350.render(load='results/putki_results')
#       8 cc1_putki.compare_with(cc1)
#
# NameError: name 'cc1_350' is not defined

# %%
cc1_putki.render(load='results/putki_results')
cc1_putki.compare_with(cc1)
# Out:
# No handles with labels found to put in legend.
# Yhteensä reward 220.49860081540177
# 10000.0 10000.0
# Työllisyysvaikutus 25-62-vuotiaisiin noin -29079.0 htv ja -1221.0 työllistä
# Työllisyysasteerp 25-62-vuotiailla noin -0.03828087818403791 prosenttia
# Epävarmuus työllisyysasteissa 0.0196, hajonta 0.04741665035469476

# %% [markdown]
# # EK:n malli
#
# Lasketaan vertailukelpoiset työllisyysasteet EK:n ehdottamalla mallilla. Mallissa on toteuttu muutoksia ansiosidonnaiseen työttömyysturvaan, asumistukeen, toimeentulotukeen ja verotukseen.

# %%
cc2=Lifecycle(env='unemploymentEK-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness)
cc2.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_ek',plot=True,
                results='results/ek_results',start_from='best/malli_ek',
                callback_minsteps=callback_minsteps)
cc2.render(load='results/ek_results')
cc2.load_sim(load='results/ek_results')

# %%
cc2.compare_with(cc1)
#print(cc1.episodestats.empstate/cc1.n_pop,cc2.episodestats.empstate/cc2.n_pop)
#cc2.episodestats.load_sim('results/ek_res__best')
#cc2.episodestats.render()

# %% [markdown]
# # Verifiointi
#
# Ajetaan sama simulaatio kaksi kertaa ja tarkastetaan että tulokset ovat sama. Tässä ideana on varmistaa, että satunnaisuus ei sotke tulosten arviointia.

# %% [markdown]
# # Työssäoloehdon pituus 12 kk
#
# Entä jos työssäoloehto olisikin 12 kuukautta pitkä nykyisen 6 kuukauden sijaan?

# %%
cc1_toe=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_toe=1.0,mortality=mortality,
                  perustulo=False,randomness=randomness)
cc1_toe.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=False,predict=True,batch1=batch1,batch2=batch2,save='best/best_12kk',plot=True,
                    results='results/12kk_results',start_from='best/best_12kk',
                callback_minsteps=callback_minsteps)
cc1_toe.render(load='results/12kk_results')

# %%
cc1_toe.compare_with(cc1)

# %% [markdown]
# # Ansiosidonnaisen päivärahan lyhennys 50 pv
#
# Tarkastellaan, miten työllisyyteen vaikuttaisi ansiosidonnaisen päivärahan lyhentäminen 50 päivällä. Tällöin alle kolmen vuoden työhistorialla ansiosidonnaisen päivärahan enimmäiskesto olisi 250 pv ja pidemmällä työhistorialla enimmäiskesto olisi 350 pv.

# %%
cc1_350=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=250,ansiopvraha_kesto400=350,
                  mortality=mortality,perustulo=False,randomness=randomness)
cc1_350.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=False,predict=True,batch1=batch1,batch2=batch2,save='best/malli_50pv',plot=True,
                    results='results/50pv_results',start_from='best/malli_50pv',cont=False,
                    callback_minsteps=callback_minsteps)
cc1_350.render(load='results/50pv_results')

# %%
cc1_350.compare_with(cc1)

# %% [markdown]
# # Perustulo

# %%
cc1_pt=Lifecycle(env='unemployment-v1',minimal=False,perustulo=True,mortality=mortality,
                 randomness=randomness)
cc1_pt.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                   train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_pt',plot=True,
                   results='results/perustulo_results',start_from='best/malli_pt',cont=False,
                callback_minsteps=callback_minsteps)
cc1_pt.render(load='results/perustulo_results')

# %%
cc1_pt.compare_with(cc1)

# %% [markdown]
# # 300 vs 400 päivän kesto ansiosidonnaisessa
#
# Mikä on alle kolmen vuoden työhistorian lyhyemmän (300 pv) ansiosidonnaisen päivärahan enimmäiskeston vaikutus työllisyyteen? Kokeillaan miten työllisyyteen vaikuttaisi sen pidentäminen 400 päivään.

# %%
cc1_400=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=400,mortality=mortality,
                  perustulo=False,randomness=randomness)
cc1_400.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_300pv',plot=True,
                    results='results/300pv_results',start_from='best/malli_300pv',cont=False,
                callback_minsteps=callback_minsteps)
cc1_400.render(load='results/300pv_results')
cc1_400.compare_with(cc1)
