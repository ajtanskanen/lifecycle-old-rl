# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisesti sosiaaliturvaa eri tiloissa.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %%
#import sys
#print(sys.path)
#sys.path.append('/usr/local/python3.7/site-packages')

# %% [markdown]
# Then load all modules and set parameters for simulations.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.15 valittaa paljon)
# ei taida toimia piilottaminen
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Populating the interactive namespace from numpy and matplotlib

# %%
# parameters for the simulation
# episode = 51 / 205 timesteps (1y/3m timestep)
pop_size=50_000 # size of the population to be simulated
size1=50_000_000 #0_000 # number of timesteps in phase 1 training (callback not used)
size2=100_000_000 #0_000 # number of timesteps in phase 2 training (callback is used to save the best results)
size3=20_000_000 # number of timesteps in phase 1 training (callback not used) for policy changes
batch1=1_00 # size of minibatch in phase 1 as number of episodes
batch2=9_00  # size of minibatch in phase 1 as number of episodes
callback_minsteps=batch2 # how many episodes callback needs 
deterministic=False # use deterministic prediction (True) or probabilitic prediction (False)
mortality=False # include mortality in computations
randomness=True # include externally given, random state-transitions (parental leaves, disability, lay-offs) 
pinkslip=True # include lay-offs at 5 percent level each year
rlmodel='acktr' # use ACKTR algorithm
twostage=False # ajataan kahdessa vaiheessa vai ei
perusmalli='best/malli_perus_week'
perusresults='results/perus_results_week'

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
cc1=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=False,timestep=1.0/12.0)
cc1.explain()
cc1.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,
                save=perusmalli,plot=True,cont=True,start_from=perusmalli,results=perusresults,
                callback_minsteps=callback_minsteps,rlmodel=rlmodel,twostage=twostage)
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.08333333333333333
# gamma 0.9930756173717006 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 63.5
# max_retirementage 68
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# include_putki None
# include_pinkslip True
#
# train...
# phase 1
# batch 9 learning rate 0.125 scaled 0.375
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:57: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/policies.py:562: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/distributions.py:323: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/distributions.py:324: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:312: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:158: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:163: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:178: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:97: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:293: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:541: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:543: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:203: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:205: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# training...
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1035: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:287: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:288: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:968: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:909: The name tf.mod is deprecated. Please use tf.math.mod instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:616: The name tf.self_adjoint_eig is deprecated. Please use tf.linalg.eigh instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:300: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:581: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ---------------------------------
# | explained_variance | 0.122    |
# | fps                | 2876     |
# | nupdates           | 1        |
# | policy_entropy     | 1.38     |
# | policy_loss        | 186      |
# | total_timesteps    | 0        |
# | value_loss         | 1.84e+04 |
# ---------------------------------
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:251: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:252: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# ---------------------------------
# | explained_variance | -0.849   |
# | fps                | 2932     |
# | nupdates           | 10       |
# | policy_entropy     | 1.19     |
# | policy_loss        | -345     |
# | total_timesteps    | 585153   |
# | value_loss         | 8.7e+04  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.514   |
# | fps                | 2902     |
# | nupdates           | 20       |
# | policy_entropy     | 1.19     |
# | policy_loss        | -216     |
# | total_timesteps    | 1235323  |
# | value_loss         | 3.38e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.461   |
# | fps                | 2895     |
# | nupdates           | 30       |
# | policy_entropy     | 1.2      |
# | policy_loss        | -210     |
# | total_timesteps    | 1885493  |
# | value_loss         | 3.14e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.564   |
# | fps                | 2893     |
# | nupdates           | 40       |
# | policy_entropy     | 1.21     |
# | policy_loss        | -199     |
# | total_timesteps    | 2535663  |
# | value_loss         | 2.78e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.279   |
# | fps                | 2893     |
# | nupdates           | 50       |
# | policy_entropy     | 1.21     |
# | policy_loss        | -184     |
# | total_timesteps    | 3185833  |
# | value_loss         | 2.39e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.535   |
# | fps                | 2892     |
# | nupdates           | 60       |
# | policy_entropy     | 1.21     |
# | policy_loss        | -167     |
# | total_timesteps    | 3836003  |
# | value_loss         | 1.98e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.88    |
# | fps                | 2892     |
# | nupdates           | 70       |
# | policy_entropy     | 1.18     |
# | policy_loss        | -149     |
# | total_timesteps    | 4486173  |
# | value_loss         | 1.65e+04 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.85    |
# | fps                | 2893     |
# | nupdates           | 80       |
# | policy_entropy     | 1.16     |
# | policy_loss        | -128     |
# | total_timesteps    | 5136343  |
# | value_loss         | 1.3e+04  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.34    |
# | fps                | 2893     |
# | nupdates           | 90       |
# | policy_entropy     | 1.14     |
# | policy_loss        | -106     |
# | total_timesteps    | 5786513  |
# | value_loss         | 9.49e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.61    |
# | fps                | 2894     |
# | nupdates           | 100      |
# | policy_entropy     | 1.13     |
# | policy_loss        | -90.6    |
# | total_timesteps    | 6436683  |
# | value_loss         | 7.34e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.14    |
# | fps                | 2894     |
# | nupdates           | 110      |
# | policy_entropy     | 1.14     |
# | policy_loss        | -81.9    |
# | total_timesteps    | 7086853  |
# | value_loss         | 6.15e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.94    |
# | fps                | 2894     |
# | nupdates           | 120      |
# | policy_entropy     | 1.13     |
# | policy_loss        | -71.5    |
# | total_timesteps    | 7737023  |
# | value_loss         | 4.96e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.88    |
# | fps                | 2894     |
# | nupdates           | 130      |
# | policy_entropy     | 1.14     |
# | policy_loss        | -60.9    |
# | total_timesteps    | 8387193  |
# | value_loss         | 3.69e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.33    |
# | fps                | 2894     |
# | nupdates           | 140      |
# | policy_entropy     | 1.15     |
# | policy_loss        | -52      |
# | total_timesteps    | 9037363  |
# | value_loss         | 2.82e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.79    |
# | fps                | 2894     |
# | nupdates           | 150      |
# | policy_entropy     | 1.16     |
# | policy_loss        | -46.5    |
# | total_timesteps    | 9687533  |
# | value_loss         | 2.24e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.36    |
# | fps                | 2894     |
# | nupdates           | 160      |
# | policy_entropy     | 1.18     |
# | policy_loss        | -40.6    |
# | total_timesteps    | 10337703 |
# | value_loss         | 1.75e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.93    |
# | fps                | 2894     |
# | nupdates           | 170      |
# | policy_entropy     | 1.2      |
# | policy_loss        | -38.4    |
# | total_timesteps    | 10987873 |
# | value_loss         | 1.51e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.09    |
# | fps                | 2894     |
# | nupdates           | 180      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -35.2    |
# | total_timesteps    | 11638043 |
# | value_loss         | 1.15e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.679   |
# | fps                | 2894     |
# | nupdates           | 190      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -31.7    |
# | total_timesteps    | 12288213 |
# | value_loss         | 912      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.164   |
# | fps                | 2894     |
# | nupdates           | 200      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -22.5    |
# | total_timesteps    | 12938383 |
# | value_loss         | 507      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.166   |
# | fps                | 2894     |
# | nupdates           | 210      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -15.1    |
# | total_timesteps    | 13588553 |
# | value_loss         | 340      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.174    |
# | fps                | 2894     |
# | nupdates           | 220      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -6.37    |
# | total_timesteps    | 14238723 |
# | value_loss         | 148      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.469    |
# | fps                | 2894     |
# | nupdates           | 230      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.775   |
# | total_timesteps    | 14888893 |
# | value_loss         | 86       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.753    |
# | fps                | 2893     |
# | nupdates           | 240      |
# | policy_entropy     | 1.24     |
# | policy_loss        | 2.14     |
# | total_timesteps    | 15539063 |
# | value_loss         | 47.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.833    |
# | fps                | 2893     |
# | nupdates           | 250      |
# | policy_entropy     | 1.24     |
# | policy_loss        | 0.165    |
# | total_timesteps    | 16189233 |
# | value_loss         | 26.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.911    |
# | fps                | 2893     |
# | nupdates           | 260      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.973   |
# | total_timesteps    | 16839403 |
# | value_loss         | 15.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.949    |
# | fps                | 2893     |
# | nupdates           | 270      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.349   |
# | total_timesteps    | 17489573 |
# | value_loss         | 9.37     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 2893     |
# | nupdates           | 280      |
# | policy_entropy     | 1.25     |
# | policy_loss        | 0.0597   |
# | total_timesteps    | 18139743 |
# | value_loss         | 6.75     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 2893     |
# | nupdates           | 290      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.316   |
# | total_timesteps    | 18789913 |
# | value_loss         | 3.99     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 2893     |
# | nupdates           | 300      |
# | policy_entropy     | 1.25     |
# | policy_loss        | 0.0543   |
# | total_timesteps    | 19440083 |
# | value_loss         | 3.46     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 2893     |
# | nupdates           | 310      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.325   |
# | total_timesteps    | 20090253 |
# | value_loss         | 2.37     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 2893     |
# | nupdates           | 320      |
# | policy_entropy     | 1.26     |
# | policy_loss        | 0.235    |
# | total_timesteps    | 20740423 |
# | value_loss         | 1.85     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 2893     |
# | nupdates           | 330      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.082   |
# | total_timesteps    | 21390593 |
# | value_loss         | 1.27     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2893     |
# | nupdates           | 340      |
# | policy_entropy     | 1.26     |
# | policy_loss        | 0.128    |
# | total_timesteps    | 22040763 |
# | value_loss         | 0.934    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2893     |
# | nupdates           | 350      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -0.0517  |
# | total_timesteps    | 22690933 |
# | value_loss         | 0.707    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 360      |
# | policy_entropy     | 1.28     |
# | policy_loss        | -0.0733  |
# | total_timesteps    | 23341103 |
# | value_loss         | 0.757    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 370      |
# | policy_entropy     | 1.28     |
# | policy_loss        | -0.12    |
# | total_timesteps    | 23991273 |
# | value_loss         | 0.572    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 380      |
# | policy_entropy     | 1.29     |
# | policy_loss        | 0.0283   |
# | total_timesteps    | 24641443 |
# | value_loss         | 0.607    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 390      |
# | policy_entropy     | 1.29     |
# | policy_loss        | 0.161    |
# | total_timesteps    | 25291613 |
# | value_loss         | 0.585    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 400      |
# | policy_entropy     | 1.28     |
# | policy_loss        | -0.0312  |
# | total_timesteps    | 25941783 |
# | value_loss         | 0.605    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 410      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -0.0483  |
# | total_timesteps    | 26591953 |
# | value_loss         | 0.524    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 420      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.0554  |
# | total_timesteps    | 27242123 |
# | value_loss         | 0.631    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 430      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.0622  |
# | total_timesteps    | 27892293 |
# | value_loss         | 0.724    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 440      |
# | policy_entropy     | 1.22     |
# | policy_loss        | 0.0515   |
# | total_timesteps    | 28542463 |
# | value_loss         | 0.591    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 450      |
# | policy_entropy     | 1.21     |
# | policy_loss        | 0.158    |
# | total_timesteps    | 29192633 |
# | value_loss         | 0.627    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2892     |
# | nupdates           | 460      |
# | policy_entropy     | 1.18     |
# | policy_loss        | -0.168   |
# | total_timesteps    | 29842803 |
# | value_loss         | 0.787    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 470      |
# | policy_entropy     | 1.16     |
# | policy_loss        | 0.0327   |
# | total_timesteps    | 30492973 |
# | value_loss         | 0.677    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2891     |
# | nupdates           | 480      |
# | policy_entropy     | 1.14     |
# | policy_loss        | 0.0299   |
# | total_timesteps    | 31143143 |
# | value_loss         | 0.986    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2891     |
# | nupdates           | 490      |
# | policy_entropy     | 1.11     |
# | policy_loss        | -0.0925  |
# | total_timesteps    | 31793313 |
# | value_loss         | 0.934    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 500      |
# | policy_entropy     | 1.1      |
# | policy_loss        | -0.0111  |
# | total_timesteps    | 32443483 |
# | value_loss         | 0.778    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 510      |
# | policy_entropy     | 1.07     |
# | policy_loss        | 0.0339   |
# | total_timesteps    | 33093653 |
# | value_loss         | 0.878    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 2891     |
# | nupdates           | 520      |
# | policy_entropy     | 1.05     |
# | policy_loss        | -0.118   |
# | total_timesteps    | 33743823 |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 530      |
# | policy_entropy     | 1.02     |
# | policy_loss        | 0.0401   |
# | total_timesteps    | 34393993 |
# | value_loss         | 0.853    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 540      |
# | policy_entropy     | 1.01     |
# | policy_loss        | 0.129    |
# | total_timesteps    | 35044163 |
# | value_loss         | 0.749    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2891     |
# | nupdates           | 550      |
# | policy_entropy     | 1.01     |
# | policy_loss        | -0.0437  |
# | total_timesteps    | 35694333 |
# | value_loss         | 1.11     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2891     |
# | nupdates           | 560      |
# | policy_entropy     | 1        |
# | policy_loss        | -0.0187  |
# | total_timesteps    | 36344503 |
# | value_loss         | 1.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2891     |
# | nupdates           | 570      |
# | policy_entropy     | 0.989    |
# | policy_loss        | -0.115   |
# | total_timesteps    | 36994673 |
# | value_loss         | 1.22     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2891     |
# | nupdates           | 580      |
# | policy_entropy     | 1.01     |
# | policy_loss        | 0.0145   |
# | total_timesteps    | 37644843 |
# | value_loss         | 0.916    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2891     |
# | nupdates           | 590      |
# | policy_entropy     | 0.976    |
# | policy_loss        | -0.0244  |
# | total_timesteps    | 38295013 |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2891     |
# | nupdates           | 600      |
# | policy_entropy     | 0.959    |
# | policy_loss        | -0.0293  |
# | total_timesteps    | 38945183 |
# | value_loss         | 0.963    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2891     |
# | nupdates           | 610      |
# | policy_entropy     | 0.97     |
# | policy_loss        | 0.0287   |
# | total_timesteps    | 39595353 |
# | value_loss         | 0.989    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2891     |
# | nupdates           | 620      |
# | policy_entropy     | 0.961    |
# | policy_loss        | 0.0522   |
# | total_timesteps    | 40245523 |
# | value_loss         | 0.845    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 630      |
# | policy_entropy     | 0.966    |
# | policy_loss        | 0.0632   |
# | total_timesteps    | 40895693 |
# | value_loss         | 0.805    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2892     |
# | nupdates           | 640      |
# | policy_entropy     | 0.951    |
# | policy_loss        | 0.0155   |
# | total_timesteps    | 41545863 |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 650      |
# | policy_entropy     | 0.956    |
# | policy_loss        | -0.0449  |
# | total_timesteps    | 42196033 |
# | value_loss         | 0.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2892     |
# | nupdates           | 660      |
# | policy_entropy     | 0.959    |
# | policy_loss        | 0.0502   |
# | total_timesteps    | 42846203 |
# | value_loss         | 1.06     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2892     |
# | nupdates           | 670      |
# | policy_entropy     | 0.953    |
# | policy_loss        | -0.0544  |
# | total_timesteps    | 43496373 |
# | value_loss         | 0.969    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2892     |
# | nupdates           | 680      |
# | policy_entropy     | 0.953    |
# | policy_loss        | -0.0458  |
# | total_timesteps    | 44146543 |
# | value_loss         | 1.29     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2892     |
# | nupdates           | 690      |
# | policy_entropy     | 0.939    |
# | policy_loss        | 0.119    |
# | total_timesteps    | 44796713 |
# | value_loss         | 0.873    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 2892     |
# | nupdates           | 700      |
# | policy_entropy     | 0.96     |
# | policy_loss        | -0.0331  |
# | total_timesteps    | 45446883 |
# | value_loss         | 1.19     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2892     |
# | nupdates           | 710      |
# | policy_entropy     | 0.942    |
# | policy_loss        | 0.0818   |
# | total_timesteps    | 46097053 |
# | value_loss         | 0.698    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2892     |
# | nupdates           | 720      |
# | policy_entropy     | 0.951    |
# | policy_loss        | -0.0198  |
# | total_timesteps    | 46747223 |
# | value_loss         | 0.981    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2892     |
# | nupdates           | 730      |
# | policy_entropy     | 0.945    |
# | policy_loss        | 0.0029   |
# | total_timesteps    | 47397393 |
# | value_loss         | 1.13     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2892     |
# | nupdates           | 740      |
# | policy_entropy     | 0.95     |
# | policy_loss        | -0.0161  |
# | total_timesteps    | 48047563 |
# | value_loss         | 1.06     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 2892     |
# | nupdates           | 750      |
# | policy_entropy     | 0.952    |
# | policy_loss        | -0.0469  |
# | total_timesteps    | 48697733 |
# | value_loss         | 1.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 2892     |
# | nupdates           | 760      |
# | policy_entropy     | 0.968    |
# | policy_loss        | -0.0475  |
# | total_timesteps    | 49347903 |
# | value_loss         | 1.12     |
# ---------------------------------
# done
# simulating  best/malli_perus_week
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=50000), HTML(value='')))
# keskimääräinen työttömyysaste 1.3818175213479749
# No handles with labels found to put in legend.
# Yhteensä reward 761.6779027263926

# %%
cc1b=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=False)
cc1b.render(load=perusresults)
# Out:
# No mortality included
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-eb78999af3a0> in <module>
#       1 cc1b=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
#       2               randomness=randomness,pinkslip=pinkslip,plotdebug=False)
# ----> 3 cc1b.render(load=perusresults)
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/lifecycle.py in render(self, load)
#     553     def render(self,load=None):
#     554         if load is not None:
# --> 555             self.episodestats.render(load=load)
#     556         else:
#     557             self.episodestats.render()
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/episodestats.py in render(self, load)
#     729
#     730         #self.plot_stats(5)
# --> 731         self.plot_stats()
#     732         #self.plot_reward()
#     733
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/episodestats.py in plot_stats(self)
#     558
#     559     def plot_stats(self):
# --> 560         self.plot_emp()
#     561         self.plot_unemp()
#     562         if not self.minimal:
#
# /Volumes/Transcend/GitHub/lifecycle-rl/lifecycle_rl/episodestats.py in plot_emp(self)
#     283         x=np.linspace(self.min_age,self.max_age,self.n_time)
#     284         fig,ax=plt.subplots()
# --> 285         ax.plot(x,tyollisyysaste,label='työllisyysaste')
#     286         ax.plot(x,tyottomyysaste,label='työttömyys')
#     287         emp_statsratio=100*self.emp_stats()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (202,) and (602,)

# %%
#cc1q=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
#              randomness=randomness,pinkslip=pinkslip,plotdebug=False)
#cc1q.explain()
#cc1q.run_results(debug=False,steps1=1_000_000,steps2=size2,pop=1_000,deterministic=deterministic,
#                train=True,predict=True,batch1=1,batch2=batch2,
#                save=perusmalli+'_dqn',plot=True,cont=False,start_from=perusmalli+'_dqn',results=perusresults+'_dqn',
#                callback_minsteps=callback_minsteps,rlmodel='dqn',twostage=False)

# %%
x=np.linspace(0,30,40)
q=np.random.uniform(20,size=20)
h,x2=np.histogram(q,x)
print(x2,h)

# %%
print(h,x2)
print(h.shape,x2.shape)

# %%
q

# %%
plt.bar(x[:-1],h)
