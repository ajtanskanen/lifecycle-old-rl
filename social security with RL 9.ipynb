# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisempi työttömyysturvamalli.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %% [markdown]
# Then load all modules.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.5 valittaa paljon)
import warnings
warnings.filterwarnings('ignore')

pop_size=1_000
steps1=10_000_000
steps2=10_000_000
batch1=1
batch2=1_000
deterministic=False
mortality=False
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
cc1=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,randomness=True,\
              deterministic=False)
cc1.explain()
cc1.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 65
# max_retirementage 70
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# deterministic False
#
# train...
# phase 1
# use_vecmonitor False
# use_callback False
# training...
# ---------------------------------
# | explained_variance | -0.0013  |
# | fps                | 1780     |
# | nupdates           | 1        |
# | policy_entropy     | 1.39     |
# | policy_loss        | 50.8     |
# | total_timesteps    | 0        |
# | value_loss         | 1.47e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.754    |
# | fps                | 2243     |
# | nupdates           | 1000     |
# | policy_entropy     | 0.505    |
# | policy_loss        | -0.195   |
# | total_timesteps    | 2458539  |
# | value_loss         | 23.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.917    |
# | fps                | 2276     |
# | nupdates           | 2000     |
# | policy_entropy     | 0.414    |
# | policy_loss        | -0.184   |
# | total_timesteps    | 4919539  |
# | value_loss         | 9.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.811    |
# | fps                | 2294     |
# | nupdates           | 3000     |
# | policy_entropy     | 0.233    |
# | policy_loss        | 0.0232   |
# | total_timesteps    | 7380539  |
# | value_loss         | 14.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.789    |
# | fps                | 2297     |
# | nupdates           | 4000     |
# | policy_entropy     | 0.246    |
# | policy_loss        | 0.00366  |
# | total_timesteps    | 9841539  |
# | value_loss         | 13.5     |
# ---------------------------------
# done
# phase 2
# use_vecmonitor True
# use_callback True
# init vecmonitor:  tmp/monitor.csv
# init resultswriter
# training...
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 214.96109 |
# | explained_variance | 0.848     |
# | fps                | 3175      |
# | nupdates           | 1         |
# | policy_entropy     | 0.278     |
# | policy_loss        | 0.0175    |
# | total_timesteps    | 0         |
# | value_loss         | 11.2      |
# ----------------------------------
# 413256 timesteps
# New best mean reward: 220.48 - Last best reward per episode: -inf
# saved as  tmp/best_perus
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.54315 |
# | explained_variance | 0.829     |
# | fps                | 3194      |
# | nupdates           | 2         |
# | policy_entropy     | 0.297     |
# | policy_loss        | -2.1      |
# | total_timesteps    | 206641    |
# | value_loss         | 77.5      |
# ----------------------------------
# 620688 timesteps
# Best mean reward: 220.48 - Last mean reward per episode: 220.25
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.03781 |
# | explained_variance | 0.824     |
# | fps                | 3200      |
# | nupdates           | 3         |
# | policy_entropy     | 0.302     |
# | policy_loss        | -1.77     |
# | total_timesteps    | 413282    |
# | value_loss         | 62        |
# ----------------------------------
# 825708 timesteps
# Best mean reward: 220.48 - Last mean reward per episode: 220.31
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.31313 |
# | explained_variance | 0.842     |
# | fps                | 3205      |
# | nupdates           | 4         |
# | policy_entropy     | 0.29      |
# | policy_loss        | 0.588     |
# | total_timesteps    | 619923    |
# | value_loss         | 15.4      |
# ----------------------------------
# 1033140 timesteps
# New best mean reward: 222.10 - Last best reward per episode: 220.48
# saved as  tmp/best_perus
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.02672 |
# | explained_variance | 0.836     |
# | fps                | 3209      |
# | nupdates           | 5         |
# | policy_entropy     | 0.277     |
# | policy_loss        | 0.447     |
# | total_timesteps    | 826564    |
# | value_loss         | 16.2      |
# ----------------------------------
# 1240572 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.14
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 214.84628 |
# | explained_variance | 0.833     |
# | fps                | 3211      |
# | nupdates           | 6         |
# | policy_entropy     | 0.285     |
# | policy_loss        | -1.47     |
# | total_timesteps    | 1033205   |
# | value_loss         | 38.5      |
# ----------------------------------
# 1445592 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.26
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.58824 |
# | explained_variance | 0.828     |
# | fps                | 3212      |
# | nupdates           | 7         |
# | policy_entropy     | 0.287     |
# | policy_loss        | -1.34     |
# | total_timesteps    | 1239846   |
# | value_loss         | 31.8      |
# ----------------------------------
# 1653024 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.76
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.48523 |
# | explained_variance | 0.837     |
# | fps                | 3213      |
# | nupdates           | 8         |
# | policy_entropy     | 0.279     |
# | policy_loss        | 0.579     |
# | total_timesteps    | 1446487   |
# | value_loss         | 22.4      |
# ----------------------------------
# 1860456 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.89
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 224.9921 |
# | explained_variance | 0.832    |
# | fps                | 3212     |
# | nupdates           | 9        |
# | policy_entropy     | 0.271    |
# | policy_loss        | 0.627    |
# | total_timesteps    | 1653128  |
# | value_loss         | 22.4     |
# ---------------------------------
# 2065476 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 219.69
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.39435 |
# | explained_variance | 0.837     |
# | fps                | 3210      |
# | nupdates           | 10        |
# | policy_entropy     | 0.277     |
# | policy_loss        | -0.825    |
# | total_timesteps    | 1859769   |
# | value_loss         | 24.2      |
# ----------------------------------
# 2272908 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.28
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.79532 |
# | explained_variance | 0.84      |
# | fps                | 3210      |
# | nupdates           | 11        |
# | policy_entropy     | 0.275     |
# | policy_loss        | -0.554    |
# | total_timesteps    | 2066410   |
# | value_loss         | 19.8      |
# ----------------------------------
# 2480340 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 222.03
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.81943 |
# | explained_variance | 0.837     |
# | fps                | 3208      |
# | nupdates           | 12        |
# | policy_entropy     | 0.27      |
# | policy_loss        | 1.03      |
# | total_timesteps    | 2273051   |
# | value_loss         | 26.6      |
# ----------------------------------
# 2685360 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.24
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.94261 |
# | explained_variance | 0.839     |
# | fps                | 3207      |
# | nupdates           | 13        |
# | policy_entropy     | 0.262     |
# | policy_loss        | 1.02      |
# | total_timesteps    | 2479692   |
# | value_loss         | 26        |
# ----------------------------------
# 2892792 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.34
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 228.16481 |
# | explained_variance | 0.83      |
# | fps                | 3207      |
# | nupdates           | 14        |
# | policy_entropy     | 0.273     |
# | policy_loss        | 1.05      |
# | total_timesteps    | 2686333   |
# | value_loss         | 26.5      |
# ----------------------------------
# 3100224 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 219.94
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.24707 |
# | explained_variance | 0.847     |
# | fps                | 3207      |
# | nupdates           | 15        |
# | policy_entropy     | 0.28      |
# | policy_loss        | 1.06      |
# | total_timesteps    | 2892974   |
# | value_loss         | 25.4      |
# ----------------------------------
# 3305244 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.14
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.38205 |
# | explained_variance | 0.849     |
# | fps                | 3206      |
# | nupdates           | 16        |
# | policy_entropy     | 0.273     |
# | policy_loss        | 1.04      |
# | total_timesteps    | 3099615   |
# | value_loss         | 25        |
# ----------------------------------
# 3512676 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.42
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.21582 |
# | explained_variance | 0.831     |
# | fps                | 3206      |
# | nupdates           | 17        |
# | policy_entropy     | 0.275     |
# | policy_loss        | 1.02      |
# | total_timesteps    | 3306256   |
# | value_loss         | 25.3      |
# ----------------------------------
# 3720108 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.45
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.23628 |
# | explained_variance | 0.837     |
# | fps                | 3205      |
# | nupdates           | 18        |
# | policy_entropy     | 0.275     |
# | policy_loss        | 0.988     |
# | total_timesteps    | 3512897   |
# | value_loss         | 24.3      |
# ----------------------------------
# 3925128 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 220.70
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.14789 |
# | explained_variance | 0.844     |
# | fps                | 3205      |
# | nupdates           | 19        |
# | policy_entropy     | 0.273     |
# | policy_loss        | 0.952     |
# | total_timesteps    | 3719538   |
# | value_loss         | 23.3      |
# ----------------------------------
# 4132560 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.67
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.08992 |
# | explained_variance | 0.845     |
# | fps                | 3204      |
# | nupdates           | 20        |
# | policy_entropy     | 0.267     |
# | policy_loss        | 0.895     |
# | total_timesteps    | 3926179   |
# | value_loss         | 22.4      |
# ----------------------------------
# 4339992 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.39
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.10968 |
# | explained_variance | 0.836     |
# | fps                | 3204      |
# | nupdates           | 21        |
# | policy_entropy     | 0.264     |
# | policy_loss        | 0.818     |
# | total_timesteps    | 4132820   |
# | value_loss         | 21.4      |
# ----------------------------------
# 4545012 timesteps
# Best mean reward: 222.10 - Last mean reward per episode: 221.52
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.01718 |
# | explained_variance | 0.852     |
# | fps                | 3203      |
# | nupdates           | 22        |
# | policy_entropy     | 0.271     |
# | policy_loss        | 0.78      |
# | total_timesteps    | 4339461   |
# | value_loss         | 19        |
# ----------------------------------
# 4752444 timesteps
# New best mean reward: 222.46 - Last best reward per episode: 222.10
# saved as  tmp/best_perus
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.75879 |
# | explained_variance | 0.848     |
# | fps                | 3203      |
# | nupdates           | 23        |
# | policy_entropy     | 0.265     |
# | policy_loss        | 0.7       |
# | total_timesteps    | 4546102   |
# | value_loss         | 18.1      |
# ----------------------------------
# 4959876 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.79
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 221.795  |
# | explained_variance | 0.837    |
# | fps                | 3203     |
# | nupdates           | 24       |
# | policy_entropy     | 0.27     |
# | policy_loss        | 0.622    |
# | total_timesteps    | 4752743  |
# | value_loss         | 17.6     |
# ---------------------------------
# 5164896 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.94
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.99077 |
# | explained_variance | 0.856     |
# | fps                | 3203      |
# | nupdates           | 25        |
# | policy_entropy     | 0.279     |
# | policy_loss        | 0.573     |
# | total_timesteps    | 4959384   |
# | value_loss         | 14.9      |
# ----------------------------------
# 5372328 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.24
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.11719 |
# | explained_variance | 0.848     |
# | fps                | 3202      |
# | nupdates           | 26        |
# | policy_entropy     | 0.271     |
# | policy_loss        | 0.46      |
# | total_timesteps    | 5166025   |
# | value_loss         | 14.6      |
# ----------------------------------
# 5579760 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.20
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 213.79404 |
# | explained_variance | 0.845     |
# | fps                | 3202      |
# | nupdates           | 27        |
# | policy_entropy     | 0.278     |
# | policy_loss        | 0.373     |
# | total_timesteps    | 5372666   |
# | value_loss         | 13.9      |
# ----------------------------------
# 5784780 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.14
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 215.18019 |
# | explained_variance | 0.846     |
# | fps                | 3202      |
# | nupdates           | 28        |
# | policy_entropy     | 0.271     |
# | policy_loss        | 0.274     |
# | total_timesteps    | 5579307   |
# | value_loss         | 12.9      |
# ----------------------------------
# 5992212 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.35
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.27538 |
# | explained_variance | 0.846     |
# | fps                | 3202      |
# | nupdates           | 29        |
# | policy_entropy     | 0.277     |
# | policy_loss        | 0.163     |
# | total_timesteps    | 5785948   |
# | value_loss         | 13        |
# ----------------------------------
# 6199644 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.74
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.91125 |
# | explained_variance | 0.837     |
# | fps                | 3202      |
# | nupdates           | 30        |
# | policy_entropy     | 0.273     |
# | policy_loss        | 0.0756    |
# | total_timesteps    | 5992589   |
# | value_loss         | 12.8      |
# ----------------------------------
# 6404664 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.99
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.84743 |
# | explained_variance | 0.853     |
# | fps                | 3202      |
# | nupdates           | 31        |
# | policy_entropy     | 0.284     |
# | policy_loss        | -0.0463   |
# | total_timesteps    | 6199230   |
# | value_loss         | 12.2      |
# ----------------------------------
# 6612096 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.97
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.67813 |
# | explained_variance | 0.855     |
# | fps                | 3202      |
# | nupdates           | 32        |
# | policy_entropy     | 0.278     |
# | policy_loss        | -0.115    |
# | total_timesteps    | 6405871   |
# | value_loss         | 11.8      |
# ----------------------------------
# 6819528 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.76
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.60722 |
# | explained_variance | 0.857     |
# | fps                | 3202      |
# | nupdates           | 33        |
# | policy_entropy     | 0.286     |
# | policy_loss        | -0.188    |
# | total_timesteps    | 6612512   |
# | value_loss         | 11.9      |
# ----------------------------------
# 7024548 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.39
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.82799 |
# | explained_variance | 0.842     |
# | fps                | 3202      |
# | nupdates           | 34        |
# | policy_entropy     | 0.283     |
# | policy_loss        | -0.249    |
# | total_timesteps    | 6819153   |
# | value_loss         | 14.2      |
# ----------------------------------
# 7231980 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.07
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.09851 |
# | explained_variance | 0.849     |
# | fps                | 3202      |
# | nupdates           | 35        |
# | policy_entropy     | 0.282     |
# | policy_loss        | -0.268    |
# | total_timesteps    | 7025794   |
# | value_loss         | 13        |
# ----------------------------------
# 7439412 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.79
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.56631 |
# | explained_variance | 0.842     |
# | fps                | 3202      |
# | nupdates           | 36        |
# | policy_entropy     | 0.277     |
# | policy_loss        | -0.292    |
# | total_timesteps    | 7232435   |
# | value_loss         | 13.9      |
# ----------------------------------
# 7644432 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.83
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.27037 |
# | explained_variance | 0.854     |
# | fps                | 3202      |
# | nupdates           | 37        |
# | policy_entropy     | 0.286     |
# | policy_loss        | -0.297    |
# | total_timesteps    | 7439076   |
# | value_loss         | 13.2      |
# ----------------------------------
# 7851864 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.78
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 224.43355 |
# | explained_variance | 0.849     |
# | fps                | 3202      |
# | nupdates           | 38        |
# | policy_entropy     | 0.28      |
# | policy_loss        | -0.274    |
# | total_timesteps    | 7645717   |
# | value_loss         | 12.5      |
# ----------------------------------
# 8059296 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.95
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 217.91379 |
# | explained_variance | 0.846     |
# | fps                | 3202      |
# | nupdates           | 39        |
# | policy_entropy     | 0.283     |
# | policy_loss        | -0.288    |
# | total_timesteps    | 7852358   |
# | value_loss         | 14.2      |
# ----------------------------------
# 8264316 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.93
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.02133 |
# | explained_variance | 0.858     |
# | fps                | 3202      |
# | nupdates           | 40        |
# | policy_entropy     | 0.287     |
# | policy_loss        | -0.257    |
# | total_timesteps    | 8058999   |
# | value_loss         | 12.4      |
# ----------------------------------
# 8471748 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.95
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.80804 |
# | explained_variance | 0.855     |
# | fps                | 3202      |
# | nupdates           | 41        |
# | policy_entropy     | 0.287     |
# | policy_loss        | -0.251    |
# | total_timesteps    | 8265640   |
# | value_loss         | 12.9      |
# ----------------------------------
# 8679180 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.81
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 219.27213 |
# | explained_variance | 0.848     |
# | fps                | 3202      |
# | nupdates           | 42        |
# | policy_entropy     | 0.277     |
# | policy_loss        | -0.212    |
# | total_timesteps    | 8472281   |
# | value_loss         | 13.1      |
# ----------------------------------
# 8884200 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.56
# ---------------------------------
# | ep_len_mean        | 201      |
# | ep_reward_mean     | 221.1986 |
# | explained_variance | 0.837    |
# | fps                | 3202     |
# | nupdates           | 43       |
# | policy_entropy     | 0.279    |
# | policy_loss        | -0.181   |
# | total_timesteps    | 8678922  |
# | value_loss         | 13.5     |
# ---------------------------------
# 9091632 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.68
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 222.80203 |
# | explained_variance | 0.855     |
# | fps                | 3202      |
# | nupdates           | 44        |
# | policy_entropy     | 0.289     |
# | policy_loss        | -0.142    |
# | total_timesteps    | 8885563   |
# | value_loss         | 12.7      |
# ----------------------------------
# 9299064 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.88
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.67244 |
# | explained_variance | 0.85      |
# | fps                | 3202      |
# | nupdates           | 45        |
# | policy_entropy     | 0.275     |
# | policy_loss        | -0.0847   |
# | total_timesteps    | 9092204   |
# | value_loss         | 11.8      |
# ----------------------------------
# 9504084 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 220.55
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 220.63008 |
# | explained_variance | 0.836     |
# | fps                | 3202      |
# | nupdates           | 46        |
# | policy_entropy     | 0.283     |
# | policy_loss        | -0.0659   |
# | total_timesteps    | 9298845   |
# | value_loss         | 13.5      |
# ----------------------------------
# 9711516 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 221.08
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 221.67314 |
# | explained_variance | 0.862     |
# | fps                | 3202      |
# | nupdates           | 47        |
# | policy_entropy     | 0.29      |
# | policy_loss        | -0.0322   |
# | total_timesteps    | 9505486   |
# | value_loss         | 11        |
# ----------------------------------
# 9918948 timesteps
# Best mean reward: 222.46 - Last mean reward per episode: 219.77
# ----------------------------------
# | ep_len_mean        | 201       |
# | ep_reward_mean     | 223.15567 |
# | explained_variance | 0.859     |
# | fps                | 3202      |
# | nupdates           | 48        |
# | policy_entropy     | 0.293     |
# | policy_loss        | -0.0295   |
# | total_timesteps    | 9712127   |
# | value_loss         | 12.1      |
# ----------------------------------
# done
# predict...
# simulating  tmp/best_perus
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=1000), HTML(value='')))
# best_emp 0
# Vaikutus työllisyysasteen keskiarvo 1394793.0 htv, mediaani 1394793.0 htv
#                         keskiarvo 1404021.0 työllistä, mediaani 1404021.0 työllistä

# %% [markdown]
# # EK:n malli
#
# Lasketaan vertailukelpoiset työllisyysasteet EK:n ehdottamalla mallilla. Mallissa on toteuttu muutoksia ansiosidonnaiseen työttömyysturvaan, asumistukeen, toimeentulotukeen ja verotukseen.

# %%
cc2=Lifecycle(env='unemploymentEK-v1',minimal=False,mortality=mortality,perustulo=False,randomness=True)
cc2.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)

# %%
#cc1.simulate(pop=10_000,deterministic=True,load='best/best_perus',rlmodel='acktr',save='perusmalli',modify_load=False)
#cc2.simulate(pop=10_000,deterministic=True,load='best/best_ek',rlmodel='acktr',save='eknmalli',modify_load=False)
cc2.compare_with(cc1)

# %% [markdown]
# # Verifiointi
#
# Ajetaan sama simulaatio kaksi kertaa ja tarkastetaan että tulokset ovat sama. Tässä ideana on varmistaa, että satunnaisuus ei sotke tulosten arviointia.

# %% [markdown]
# # 300 vs 400 päivän kesto ansiosidonnaisessa
#
# Mikä on alle kolmen vuoden työhistorian lyhyemmän (300 pv) ansiosidonnaisen päivärahan enimmäiskeston vaikutus työllisyyteen? Kokeillaan miten työllisyyteen vaikuttaisi sen pidentäminen 400 päivään.

# %%
cc1_400=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=400,mortality=mortality,\
                  perustulo=False,randomness=True
cc1_400.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)
cc1_400.compare_with(cc1)

# %% [markdown]
# # Työssäoloehdon pituus 12 kk
#
# Entä jos työssäoloehto olisikin 12 kuukautta pitkä nykyisen 6 kuukauden sijaan?

# %%
cc1_toe=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_toe=1.0,mortality=mortality,\
                  perustulo=False,randomness=True
cc1_toe.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)

# %%
cc1_toe.compare_with(cc1)

# %% [markdown]
# # Ansiosidonnaisen päivärahan lyhennys 50 pv
#
# Tarkastellaan, miten työllisyyteen vaikuttaisi ansiosidonnaisen päivärahan lyhentäminen 50 päivällä. Tällöin alle kolmen vuoden työhistorialla ansiosidonnaisen päivärahan enimmäiskesto olisi 250 pv ja pidemmällä työhistorialla enimmäiskesto olisi 350 pv.

# %%
cc1_350=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=250,ansiopvraha_kesto400=350,\
                  mortality=mortality,perustulo=False,randomness=True
cc1_350.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)

# %%
cc1_350.compare_with(cc1)

# %% [markdown]
# # Työttömyysputken poisto
#
# Työttömyysputki on suosittu elinkaarimalleissa. Tarkastellaan millainen työllisyysvaikutus on putken poistamisella.

# %%
cc1_putki=Lifecycle(env='unemployment-v1',minimal=False,include_putki=False,mortality=mortality,\
                    perustulo=False,randomness=True
cc1_putki.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)
cc1_putki.compare_with(cc1)

# %% [markdown]
# # Perustulo

# %%
cc1_pt=Lifecycle(env='unemployment-v1',minimal=False,perustulo=True,mortality=mortality,randomness=True
cc1_pt.run_results(debug=False,steps1=steps1,steps2=steps2,n=0,pop=pop_size,deterministic=deterministic,\
               train=True,predict=True,batch1=batch1,batch2=batch2,bestname='best_perus',plot=True)

# %%
cc1_pt.compare_with(cc1)
