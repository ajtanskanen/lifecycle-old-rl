# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisesti sosiaaliturvaa eri tiloissa.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %%
#import sys
#print(sys.path)
#sys.path.append('/usr/local/python3.7/site-packages')

# %% [markdown]
# Then load all modules and set parameters for simulations.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle,OptimizeLifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.15 valittaa paljon)
# ei taida toimia piilottaminen
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Populating the interactive namespace from numpy and matplotlib

# %%
# parameters for the simulation
# episode = 51 / 205 timesteps (1y/3m timestep)
pop_size=5_000 # size of the population to be simulated
size1=5_000_000 # number of timesteps in phase 1 training (callback not used)
size2=100_000_000 #0_000 # number of timesteps in phase 2 training (callback is used to save the best results)
size3=20_000_000 # number of timesteps in phase 1 training (callback not used) for policy changes
batch1=8 # size of minibatch in phase 1 as number of episodes
batch2=9_00  # size of minibatch in phase 1 as number of episodes
callback_minsteps=batch2 # how many episodes callback needs 
deterministic=True # use deterministic prediction (True) or probabilitic prediction (False)
mortality=False # include mortality in computations
randomness=True # include externally given, random state-transitions (parental leaves, disability, lay-offs) 
pinkslip=True # include lay-offs at 5 percent level each year
rlmodel='acktr' # use ACKTR algorithm
twostage=False # ajataan kahdessa vaiheessa vai ei
perusmalli_start='best/v2_malli_base_dev'
perusmalli='best/v2_malli_base_dev_v3'
perusresults='results/v2_malli_base_dev_stoch'
prefmalli='best/v2_malli_perus_prefnoise'
prefresults='results/v2_perus_results_prefnoise'
debug=False # jos True, niin ajetaan vain yhdellä prosessilla. Nopeampi debugata.
plotdebug=False # tulostetaanko rivi riviltä mitä tapahtuu

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
kw1={'env':'unemployment-v2','minimal':False,'mortality':mortality,'perustulo':False,
     'randomness':randomness,'pinkslip':pinkslip,'plotdebug':plotdebug}
kw2={'debug':debug,'steps1':size1,'steps2':size2,'pop':pop_size,
     'deterministic':deterministic,'train':True,'predict':True,'batch1':batch1,
     'batch2':batch2,'save':perusmalli,'plot':False,'cont':True,
     'start_from':perusmalli_start,'results':perusresults,
     'callback_minsteps':callback_minsteps,'rlmodel':rlmodel,'twostage':twostage,
     'learning_rate':0.05,'learning_schedule':'constant'}
cc=OptimizeLifecycle(initargs=kw1,runargs=kw2)
cc.optimize()
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 63.5
# max_retirementage 68
# ansiopvraha_kesto300 300
# ansiopvraha_kesto400 400
# ansiopvraha_toe 0.5
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# include_putki True
# include_pinkslip True
# sigma_reduction True
# plotdebug False
#
# {'men_kappa_fulltime': 0.42510660141077217, 'men_kappa_parttime': 0.5881297973768632, 'women_kappa_fulltime': 0.30003431244520345, 'women_kappa_parttime': 0.4209330290527359}
# train...
# phase 1
# batch 1 learning rate 0.0125 scaled 0.0125
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:177: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:182: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:197: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:99: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:298: The name tf.diag is deprecated. Please use tf.linalg.tensor_diag instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:546: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:548: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:222: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:224: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# training...
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1143: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:307: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:308: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:973: The name tf.train.MomentumOptimizer is deprecated. Please use tf.compat.v1.train.MomentumOptimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:914: The name tf.mod is deprecated. Please use tf.math.mod instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/kfac.py:621: The name tf.self_adjoint_eig is deprecated. Please use tf.linalg.eigh instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:320: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ---------------------------------
# | explained_variance | 0.775    |
# | fps                | 1119     |
# | nupdates           | 1        |
# | policy_entropy     | 1.39     |
# | policy_loss        | -4.11    |
# | total_timesteps    | 1616     |
# | value_loss         | 11.7     |
# ---------------------------------
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:270: The name tf.RunOptions is deprecated. Please use tf.compat.v1.RunOptions instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py:271: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# ---------------------------------
# | explained_variance | 0.854    |
# | fps                | 2470     |
# | nupdates           | 10       |
# | policy_entropy     | 1.39     |
# | policy_loss        | 1.99     |
# | total_timesteps    | 16160    |
# | value_loss         | 4.2      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.856    |
# | fps                | 2235     |
# | nupdates           | 20       |
# | policy_entropy     | 1.39     |
# | policy_loss        | 0.909    |
# | total_timesteps    | 32320    |
# | value_loss         | 2.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.866    |
# | fps                | 2170     |
# | nupdates           | 30       |
# | policy_entropy     | 1.39     |
# | policy_loss        | -1.56    |
# | total_timesteps    | 48480    |
# | value_loss         | 3.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.901    |
# | fps                | 2109     |
# | nupdates           | 40       |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.206   |
# | total_timesteps    | 64640    |
# | value_loss         | 1.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.923    |
# | fps                | 2038     |
# | nupdates           | 50       |
# | policy_entropy     | 1.38     |
# | policy_loss        | 1.19     |
# | total_timesteps    | 80800    |
# | value_loss         | 1.66     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.923    |
# | fps                | 2004     |
# | nupdates           | 60       |
# | policy_entropy     | 1.38     |
# | policy_loss        | -1.01    |
# | total_timesteps    | 96960    |
# | value_loss         | 1.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.908    |
# | fps                | 2005     |
# | nupdates           | 70       |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.372   |
# | total_timesteps    | 113120   |
# | value_loss         | 1.24     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 1999     |
# | nupdates           | 80       |
# | policy_entropy     | 1.38     |
# | policy_loss        | 0.805    |
# | total_timesteps    | 129280   |
# | value_loss         | 1.28     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 2004     |
# | nupdates           | 90       |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.626   |
# | total_timesteps    | 145440   |
# | value_loss         | 0.787    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.942    |
# | fps                | 2007     |
# | nupdates           | 100      |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.0121  |
# | total_timesteps    | 161600   |
# | value_loss         | 0.817    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.942    |
# | fps                | 2012     |
# | nupdates           | 110      |
# | policy_entropy     | 1.38     |
# | policy_loss        | 0.382    |
# | total_timesteps    | 177760   |
# | value_loss         | 0.843    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 2009     |
# | nupdates           | 120      |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.197   |
# | total_timesteps    | 193920   |
# | value_loss         | 0.636    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 2012     |
# | nupdates           | 130      |
# | policy_entropy     | 1.38     |
# | policy_loss        | -0.0649  |
# | total_timesteps    | 210080   |
# | value_loss         | 0.528    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.935    |
# | fps                | 2014     |
# | nupdates           | 140      |
# | policy_entropy     | 1.38     |
# | policy_loss        | 0.0304   |
# | total_timesteps    | 226240   |
# | value_loss         | 0.889    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.93     |
# | fps                | 2018     |
# | nupdates           | 150      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.014   |
# | total_timesteps    | 242400   |
# | value_loss         | 0.844    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 2010     |
# | nupdates           | 160      |
# | policy_entropy     | 1.37     |
# | policy_loss        | 0.0667   |
# | total_timesteps    | 258560   |
# | value_loss         | 0.51     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 2011     |
# | nupdates           | 170      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.0781  |
# | total_timesteps    | 274720   |
# | value_loss         | 0.616    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 2012     |
# | nupdates           | 180      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.0163  |
# | total_timesteps    | 290880   |
# | value_loss         | 0.606    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.934    |
# | fps                | 2010     |
# | nupdates           | 190      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.148   |
# | total_timesteps    | 307040   |
# | value_loss         | 0.663    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 2007     |
# | nupdates           | 200      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.119   |
# | total_timesteps    | 323200   |
# | value_loss         | 0.739    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 2006     |
# | nupdates           | 210      |
# | policy_entropy     | 1.37     |
# | policy_loss        | 0.045    |
# | total_timesteps    | 339360   |
# | value_loss         | 0.566    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 2008     |
# | nupdates           | 220      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.101   |
# | total_timesteps    | 355520   |
# | value_loss         | 0.469    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.967    |
# | fps                | 2005     |
# | nupdates           | 230      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.0544  |
# | total_timesteps    | 371680   |
# | value_loss         | 0.439    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.945    |
# | fps                | 2006     |
# | nupdates           | 240      |
# | policy_entropy     | 1.37     |
# | policy_loss        | -0.0164  |
# | total_timesteps    | 387840   |
# | value_loss         | 0.792    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 2006     |
# | nupdates           | 250      |
# | policy_entropy     | 1.36     |
# | policy_loss        | 0.116    |
# | total_timesteps    | 404000   |
# | value_loss         | 0.705    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 2008     |
# | nupdates           | 260      |
# | policy_entropy     | 1.36     |
# | policy_loss        | -0.0149  |
# | total_timesteps    | 420160   |
# | value_loss         | 0.495    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 2005     |
# | nupdates           | 270      |
# | policy_entropy     | 1.36     |
# | policy_loss        | -0.0647  |
# | total_timesteps    | 436320   |
# | value_loss         | 0.425    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 2007     |
# | nupdates           | 280      |
# | policy_entropy     | 1.36     |
# | policy_loss        | 0.0181   |
# | total_timesteps    | 452480   |
# | value_loss         | 0.498    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.956    |
# | fps                | 2008     |
# | nupdates           | 290      |
# | policy_entropy     | 1.36     |
# | policy_loss        | 0.00278  |
# | total_timesteps    | 468640   |
# | value_loss         | 0.658    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 2007     |
# | nupdates           | 300      |
# | policy_entropy     | 1.35     |
# | policy_loss        | -0.102   |
# | total_timesteps    | 484800   |
# | value_loss         | 0.443    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.967    |
# | fps                | 2005     |
# | nupdates           | 310      |
# | policy_entropy     | 1.35     |
# | policy_loss        | 0.123    |
# | total_timesteps    | 500960   |
# | value_loss         | 0.461    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 2006     |
# | nupdates           | 320      |
# | policy_entropy     | 1.34     |
# | policy_loss        | -0.134   |
# | total_timesteps    | 517120   |
# | value_loss         | 0.604    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2007     |
# | nupdates           | 330      |
# | policy_entropy     | 1.34     |
# | policy_loss        | -0.0237  |
# | total_timesteps    | 533280   |
# | value_loss         | 0.389    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 2004     |
# | nupdates           | 340      |
# | policy_entropy     | 1.33     |
# | policy_loss        | 0.0887   |
# | total_timesteps    | 549440   |
# | value_loss         | 0.412    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 2002     |
# | nupdates           | 350      |
# | policy_entropy     | 1.33     |
# | policy_loss        | -0.0391  |
# | total_timesteps    | 565600   |
# | value_loss         | 0.403    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 2004     |
# | nupdates           | 360      |
# | policy_entropy     | 1.33     |
# | policy_loss        | 0.0973   |
# | total_timesteps    | 581760   |
# | value_loss         | 0.247    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.976    |
# | fps                | 2004     |
# | nupdates           | 370      |
# | policy_entropy     | 1.32     |
# | policy_loss        | -0.0208  |
# | total_timesteps    | 597920   |
# | value_loss         | 0.298    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 1997     |
# | nupdates           | 380      |
# | policy_entropy     | 1.32     |
# | policy_loss        | -0.00768 |
# | total_timesteps    | 614080   |
# | value_loss         | 0.378    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 1995     |
# | nupdates           | 390      |
# | policy_entropy     | 1.32     |
# | policy_loss        | -0.111   |
# | total_timesteps    | 630240   |
# | value_loss         | 0.361    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 1995     |
# | nupdates           | 400      |
# | policy_entropy     | 1.31     |
# | policy_loss        | -0.275   |
# | total_timesteps    | 646400   |
# | value_loss         | 0.734    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.974    |
# | fps                | 1993     |
# | nupdates           | 410      |
# | policy_entropy     | 1.31     |
# | policy_loss        | 0.0267   |
# | total_timesteps    | 662560   |
# | value_loss         | 0.297    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 1993     |
# | nupdates           | 420      |
# | policy_entropy     | 1.31     |
# | policy_loss        | -0.0246  |
# | total_timesteps    | 678720   |
# | value_loss         | 0.24     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.97     |
# | fps                | 1994     |
# | nupdates           | 430      |
# | policy_entropy     | 1.31     |
# | policy_loss        | -0.0284  |
# | total_timesteps    | 694880   |
# | value_loss         | 0.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.977    |
# | fps                | 1994     |
# | nupdates           | 440      |
# | policy_entropy     | 1.3      |
# | policy_loss        | -0.0351  |
# | total_timesteps    | 711040   |
# | value_loss         | 0.244    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1993     |
# | nupdates           | 450      |
# | policy_entropy     | 1.3      |
# | policy_loss        | 0.0571   |
# | total_timesteps    | 727200   |
# | value_loss         | 0.31     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.969    |
# | fps                | 1993     |
# | nupdates           | 460      |
# | policy_entropy     | 1.3      |
# | policy_loss        | -0.03    |
# | total_timesteps    | 743360   |
# | value_loss         | 0.371    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1994     |
# | nupdates           | 470      |
# | policy_entropy     | 1.3      |
# | policy_loss        | 0.0921   |
# | total_timesteps    | 759520   |
# | value_loss         | 0.302    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 1994     |
# | nupdates           | 480      |
# | policy_entropy     | 1.3      |
# | policy_loss        | -0.0108  |
# | total_timesteps    | 775680   |
# | value_loss         | 0.244    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1993     |
# | nupdates           | 490      |
# | policy_entropy     | 1.3      |
# | policy_loss        | -0.0782  |
# | total_timesteps    | 791840   |
# | value_loss         | 0.29     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1994     |
# | nupdates           | 500      |
# | policy_entropy     | 1.29     |
# | policy_loss        | -0.0338  |
# | total_timesteps    | 808000   |
# | value_loss         | 0.211    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1994     |
# | nupdates           | 510      |
# | policy_entropy     | 1.29     |
# | policy_loss        | -0.0103  |
# | total_timesteps    | 824160   |
# | value_loss         | 0.227    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 1994     |
# | nupdates           | 520      |
# | policy_entropy     | 1.29     |
# | policy_loss        | 0.00317  |
# | total_timesteps    | 840320   |
# | value_loss         | 0.181    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1993     |
# | nupdates           | 530      |
# | policy_entropy     | 1.28     |
# | policy_loss        | 0.0225   |
# | total_timesteps    | 856480   |
# | value_loss         | 0.275    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1994     |
# | nupdates           | 540      |
# | policy_entropy     | 1.29     |
# | policy_loss        | -0.0776  |
# | total_timesteps    | 872640   |
# | value_loss         | 0.266    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.968    |
# | fps                | 1994     |
# | nupdates           | 550      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -0.0795  |
# | total_timesteps    | 888800   |
# | value_loss         | 0.48     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.986    |
# | fps                | 1993     |
# | nupdates           | 560      |
# | policy_entropy     | 1.28     |
# | policy_loss        | -0.0614  |
# | total_timesteps    | 904960   |
# | value_loss         | 0.193    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 1994     |
# | nupdates           | 570      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -0.0647  |
# | total_timesteps    | 921120   |
# | value_loss         | 0.26     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 1995     |
# | nupdates           | 580      |
# | policy_entropy     | 1.28     |
# | policy_loss        | 0.00356  |
# | total_timesteps    | 937280   |
# | value_loss         | 0.192    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 1995     |
# | nupdates           | 590      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.0351  |
# | total_timesteps    | 953440   |
# | value_loss         | 0.184    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1994     |
# | nupdates           | 600      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.0766  |
# | total_timesteps    | 969600   |
# | value_loss         | 0.203    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 1994     |
# | nupdates           | 610      |
# | policy_entropy     | 1.27     |
# | policy_loss        | 0.0527   |
# | total_timesteps    | 985760   |
# | value_loss         | 0.197    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 1995     |
# | nupdates           | 620      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.0148  |
# | total_timesteps    | 1001920  |
# | value_loss         | 0.194    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 1995     |
# | nupdates           | 630      |
# | policy_entropy     | 1.27     |
# | policy_loss        | -0.055   |
# | total_timesteps    | 1018080  |
# | value_loss         | 0.213    |
# ---------------------------------
# ----------------------------------
# | explained_variance | 0.986     |
# | fps                | 1994      |
# | nupdates           | 640       |
# | policy_entropy     | 1.26      |
# | policy_loss        | -0.000354 |
# | total_timesteps    | 1034240   |
# | value_loss         | 0.181     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 1995     |
# | nupdates           | 650      |
# | policy_entropy     | 1.26     |
# | policy_loss        | 0.00226  |
# | total_timesteps    | 1050400  |
# | value_loss         | 0.154    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 1995     |
# | nupdates           | 660      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.0466  |
# | total_timesteps    | 1066560  |
# | value_loss         | 0.197    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 1994     |
# | nupdates           | 670      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.00467 |
# | total_timesteps    | 1082720  |
# | value_loss         | 0.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 1994     |
# | nupdates           | 680      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.0366  |
# | total_timesteps    | 1098880  |
# | value_loss         | 0.225    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 1995     |
# | nupdates           | 690      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.008   |
# | total_timesteps    | 1115040  |
# | value_loss         | 0.105    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 1995     |
# | nupdates           | 700      |
# | policy_entropy     | 1.24     |
# | policy_loss        | 0.0209   |
# | total_timesteps    | 1131200  |
# | value_loss         | 0.175    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 1994     |
# | nupdates           | 710      |
# | policy_entropy     | 1.26     |
# | policy_loss        | -0.00647 |
# | total_timesteps    | 1147360  |
# | value_loss         | 0.209    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 1995     |
# | nupdates           | 720      |
# | policy_entropy     | 1.25     |
# | policy_loss        | -0.0379  |
# | total_timesteps    | 1163520  |
# | value_loss         | 0.172    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 1995     |
# | nupdates           | 730      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.0607  |
# | total_timesteps    | 1179680  |
# | value_loss         | 0.14     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 1996     |
# | nupdates           | 740      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.00292 |
# | total_timesteps    | 1195840  |
# | value_loss         | 0.13     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1995     |
# | nupdates           | 750      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0149  |
# | total_timesteps    | 1212000  |
# | value_loss         | 0.108    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1995     |
# | nupdates           | 760      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.00824 |
# | total_timesteps    | 1228160  |
# | value_loss         | 0.126    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 1996     |
# | nupdates           | 770      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.00974 |
# | total_timesteps    | 1244320  |
# | value_loss         | 0.133    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1996     |
# | nupdates           | 780      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.0415  |
# | total_timesteps    | 1260480  |
# | value_loss         | 0.115    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.988    |
# | fps                | 1995     |
# | nupdates           | 790      |
# | policy_entropy     | 1.25     |
# | policy_loss        | 0.0159   |
# | total_timesteps    | 1276640  |
# | value_loss         | 0.138    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1995     |
# | nupdates           | 800      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0394  |
# | total_timesteps    | 1292800  |
# | value_loss         | 0.124    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1996     |
# | nupdates           | 810      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.00695 |
# | total_timesteps    | 1308960  |
# | value_loss         | 0.118    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1995     |
# | nupdates           | 820      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.00695 |
# | total_timesteps    | 1325120  |
# | value_loss         | 0.121    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 1995     |
# | nupdates           | 830      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0463  |
# | total_timesteps    | 1341280  |
# | value_loss         | 0.163    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1996     |
# | nupdates           | 840      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.021   |
# | total_timesteps    | 1357440  |
# | value_loss         | 0.111    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1996     |
# | nupdates           | 850      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0428  |
# | total_timesteps    | 1373600  |
# | value_loss         | 0.0883   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.99     |
# | fps                | 1996     |
# | nupdates           | 860      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0746  |
# | total_timesteps    | 1389760  |
# | value_loss         | 0.131    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1996     |
# | nupdates           | 870      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0122  |
# | total_timesteps    | 1405920  |
# | value_loss         | 0.106    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.989    |
# | fps                | 1996     |
# | nupdates           | 880      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0107  |
# | total_timesteps    | 1422080  |
# | value_loss         | 0.166    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1997     |
# | nupdates           | 890      |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0239  |
# | total_timesteps    | 1438240  |
# | value_loss         | 0.0917   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1996     |
# | nupdates           | 900      |
# | policy_entropy     | 1.24     |
# | policy_loss        | -0.0552  |
# | total_timesteps    | 1454400  |
# | value_loss         | 0.137    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1997     |
# | nupdates           | 910      |
# | policy_entropy     | 1.21     |
# | policy_loss        | 0.0199   |
# | total_timesteps    | 1470560  |
# | value_loss         | 0.0981   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1997     |
# | nupdates           | 920      |
# | policy_entropy     | 1.21     |
# | policy_loss        | -0.0164  |
# | total_timesteps    | 1486720  |
# | value_loss         | 0.0941   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1996     |
# | nupdates           | 930      |
# | policy_entropy     | 1.21     |
# | policy_loss        | -0.0165  |
# | total_timesteps    | 1502880  |
# | value_loss         | 0.0886   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1996     |
# | nupdates           | 940      |
# | policy_entropy     | 1.2      |
# | policy_loss        | 0.0056   |
# | total_timesteps    | 1519040  |
# | value_loss         | 0.0997   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 950      |
# | policy_entropy     | 1.21     |
# | policy_loss        | 0.0302   |
# | total_timesteps    | 1535200  |
# | value_loss         | 0.0788   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1997     |
# | nupdates           | 960      |
# | policy_entropy     | 1.22     |
# | policy_loss        | 0.00904  |
# | total_timesteps    | 1551360  |
# | value_loss         | 0.102    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 970      |
# | policy_entropy     | 1.22     |
# | policy_loss        | -0.0293  |
# | total_timesteps    | 1567520  |
# | value_loss         | 0.0766   |
# ---------------------------------
# ----------------------------------
# | explained_variance | 0.991     |
# | fps                | 1997      |
# | nupdates           | 980       |
# | policy_entropy     | 1.22      |
# | policy_loss        | -0.000404 |
# | total_timesteps    | 1583680   |
# | value_loss         | 0.124     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 990      |
# | policy_entropy     | 1.2      |
# | policy_loss        | 0.0267   |
# | total_timesteps    | 1599840  |
# | value_loss         | 0.0805   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1000     |
# | policy_entropy     | 1.19     |
# | policy_loss        | 0.0349   |
# | total_timesteps    | 1616000  |
# | value_loss         | 0.0759   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1997     |
# | nupdates           | 1010     |
# | policy_entropy     | 1.2      |
# | policy_loss        | -0.0132  |
# | total_timesteps    | 1632160  |
# | value_loss         | 0.0649   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1997     |
# | nupdates           | 1020     |
# | policy_entropy     | 1.23     |
# | policy_loss        | -0.0146  |
# | total_timesteps    | 1648320  |
# | value_loss         | 0.0614   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1997     |
# | nupdates           | 1030     |
# | policy_entropy     | 1.2      |
# | policy_loss        | -0.0131  |
# | total_timesteps    | 1664480  |
# | value_loss         | 0.0584   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 1040     |
# | policy_entropy     | 1.21     |
# | policy_loss        | 0.00674  |
# | total_timesteps    | 1680640  |
# | value_loss         | 0.0921   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 1050     |
# | policy_entropy     | 1.21     |
# | policy_loss        | -0.0671  |
# | total_timesteps    | 1696800  |
# | value_loss         | 0.0786   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 1060     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0245  |
# | total_timesteps    | 1712960  |
# | value_loss         | 0.0831   |
# ---------------------------------
# ----------------------------------
# | explained_variance | 0.995     |
# | fps                | 1997      |
# | nupdates           | 1070      |
# | policy_entropy     | 1.2       |
# | policy_loss        | -0.000929 |
# | total_timesteps    | 1729120   |
# | value_loss         | 0.0568    |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1997     |
# | nupdates           | 1080     |
# | policy_entropy     | 1.2      |
# | policy_loss        | 0.0198   |
# | total_timesteps    | 1745280  |
# | value_loss         | 0.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1997     |
# | nupdates           | 1090     |
# | policy_entropy     | 1.22     |
# | policy_loss        | -0.0271  |
# | total_timesteps    | 1761440  |
# | value_loss         | 0.0796   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1998     |
# | nupdates           | 1100     |
# | policy_entropy     | 1.18     |
# | policy_loss        | -0.00226 |
# | total_timesteps    | 1777600  |
# | value_loss         | 0.083    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1998     |
# | nupdates           | 1110     |
# | policy_entropy     | 1.19     |
# | policy_loss        | 0.018    |
# | total_timesteps    | 1793760  |
# | value_loss         | 0.276    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1120     |
# | policy_entropy     | 1.2      |
# | policy_loss        | -0.00111 |
# | total_timesteps    | 1809920  |
# | value_loss         | 0.0569   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1130     |
# | policy_entropy     | 1.18     |
# | policy_loss        | 0.0165   |
# | total_timesteps    | 1826080  |
# | value_loss         | 0.0715   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1140     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0317  |
# | total_timesteps    | 1842240  |
# | value_loss         | 0.0666   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 1998     |
# | nupdates           | 1150     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0419  |
# | total_timesteps    | 1858400  |
# | value_loss         | 0.116    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1160     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0196  |
# | total_timesteps    | 1874560  |
# | value_loss         | 0.0633   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1998     |
# | nupdates           | 1170     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0556  |
# | total_timesteps    | 1890720  |
# | value_loss         | 0.0708   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1180     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.00439 |
# | total_timesteps    | 1906880  |
# | value_loss         | 0.053    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1190     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.00638 |
# | total_timesteps    | 1923040  |
# | value_loss         | 0.0558   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1998     |
# | nupdates           | 1200     |
# | policy_entropy     | 1.16     |
# | policy_loss        | 0.0162   |
# | total_timesteps    | 1939200  |
# | value_loss         | 0.0589   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 1998     |
# | nupdates           | 1210     |
# | policy_entropy     | 1.21     |
# | policy_loss        | -0.123   |
# | total_timesteps    | 1955360  |
# | value_loss         | 0.0985   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1220     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.00594 |
# | total_timesteps    | 1971520  |
# | value_loss         | 0.0625   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1998     |
# | nupdates           | 1230     |
# | policy_entropy     | 1.2      |
# | policy_loss        | 0.0244   |
# | total_timesteps    | 1987680  |
# | value_loss         | 0.0977   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1998     |
# | nupdates           | 1240     |
# | policy_entropy     | 1.17     |
# | policy_loss        | -0.0162  |
# | total_timesteps    | 2003840  |
# | value_loss         | 0.103    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1999     |
# | nupdates           | 1250     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0232  |
# | total_timesteps    | 2020000  |
# | value_loss         | 0.091    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1260     |
# | policy_entropy     | 1.2      |
# | policy_loss        | 0.00227  |
# | total_timesteps    | 2036160  |
# | value_loss         | 0.0528   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1998     |
# | nupdates           | 1270     |
# | policy_entropy     | 1.22     |
# | policy_loss        | 0.044    |
# | total_timesteps    | 2052320  |
# | value_loss         | 0.105    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1280     |
# | policy_entropy     | 1.16     |
# | policy_loss        | 0.000142 |
# | total_timesteps    | 2068480  |
# | value_loss         | 0.0457   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1999     |
# | nupdates           | 1290     |
# | policy_entropy     | 1.17     |
# | policy_loss        | -0.0737  |
# | total_timesteps    | 2084640  |
# | value_loss         | 0.0696   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1300     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 1.54e-05 |
# | total_timesteps    | 2100800  |
# | value_loss         | 0.048    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1310     |
# | policy_entropy     | 1.19     |
# | policy_loss        | -0.0117  |
# | total_timesteps    | 2116960  |
# | value_loss         | 0.056    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1320     |
# | policy_entropy     | 1.15     |
# | policy_loss        | -0.00853 |
# | total_timesteps    | 2133120  |
# | value_loss         | 0.0556   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1999     |
# | nupdates           | 1330     |
# | policy_entropy     | 1.18     |
# | policy_loss        | -0.0375  |
# | total_timesteps    | 2149280  |
# | value_loss         | 0.0653   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 1998     |
# | nupdates           | 1340     |
# ...
# | value_loss         | 0.045    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1989     |
# | nupdates           | 1420     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.0427  |
# | total_timesteps    | 2294720  |
# | value_loss         | 0.0544   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1989     |
# | nupdates           | 1430     |
# | policy_entropy     | 1.18     |
# | policy_loss        | 0.0296   |
# | total_timesteps    | 2310880  |
# | value_loss         | 0.0663   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1990     |
# | nupdates           | 1440     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 0.00397  |
# | total_timesteps    | 2327040  |
# | value_loss         | 0.046    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1991     |
# | nupdates           | 1450     |
# | policy_entropy     | 1.17     |
# | policy_loss        | -0.0226  |
# | total_timesteps    | 2343200  |
# | value_loss         | 0.0468   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1991     |
# | nupdates           | 1460     |
# | policy_entropy     | 1.17     |
# | policy_loss        | 0.014    |
# | total_timesteps    | 2359360  |
# | value_loss         | 0.0535   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1992     |
# | nupdates           | 1470     |
# | policy_entropy     | 1.13     |
# | policy_loss        | -0.0441  |
# | total_timesteps    | 2375520  |
# | value_loss         | 0.0552   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1992     |
# | nupdates           | 1480     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 0.019    |
# | total_timesteps    | 2391680  |
# | value_loss         | 0.0369   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1993     |
# | nupdates           | 1490     |
# | policy_entropy     | 1.15     |
# | policy_loss        | -0.0389  |
# | total_timesteps    | 2407840  |
# | value_loss         | 0.0453   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1993     |
# | nupdates           | 1500     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.0244  |
# | total_timesteps    | 2424000  |
# | value_loss         | 0.072    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 1994     |
# | nupdates           | 1510     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 0.00621  |
# | total_timesteps    | 2440160  |
# | value_loss         | 0.102    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1995     |
# | nupdates           | 1520     |
# | policy_entropy     | 1.17     |
# | policy_loss        | -0.0301  |
# | total_timesteps    | 2456320  |
# | value_loss         | 0.0474   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1995     |
# | nupdates           | 1530     |
# | policy_entropy     | 1.11     |
# | policy_loss        | -0.00503 |
# | total_timesteps    | 2472480  |
# | value_loss         | 0.0365   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 1996     |
# | nupdates           | 1540     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 0.0344   |
# | total_timesteps    | 2488640  |
# | value_loss         | 0.0414   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1996     |
# | nupdates           | 1550     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.033   |
# | total_timesteps    | 2504800  |
# | value_loss         | 0.0503   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1997     |
# | nupdates           | 1560     |
# | policy_entropy     | 1.16     |
# | policy_loss        | 0.00582  |
# | total_timesteps    | 2520960  |
# | value_loss         | 0.0461   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1998     |
# | nupdates           | 1570     |
# | policy_entropy     | 1.15     |
# | policy_loss        | 0.00168  |
# | total_timesteps    | 2537120  |
# | value_loss         | 0.0347   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1998     |
# | nupdates           | 1580     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.0425  |
# | total_timesteps    | 2553280  |
# | value_loss         | 0.0461   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 1998     |
# | nupdates           | 1590     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.0713  |
# | total_timesteps    | 2569440  |
# | value_loss         | 0.0723   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1600     |
# | policy_entropy     | 1.13     |
# | policy_loss        | 0.0431   |
# | total_timesteps    | 2585600  |
# | value_loss         | 0.0535   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 2000     |
# | nupdates           | 1610     |
# | policy_entropy     | 1.17     |
# | policy_loss        | -0.0625  |
# | total_timesteps    | 2601760  |
# | value_loss         | 0.0412   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 2000     |
# | nupdates           | 1620     |
# | policy_entropy     | 1.18     |
# | policy_loss        | -0.0436  |
# | total_timesteps    | 2617920  |
# | value_loss         | 0.0448   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 2000     |
# | nupdates           | 1630     |
# | policy_entropy     | 1.11     |
# | policy_loss        | 0.0119   |
# | total_timesteps    | 2634080  |
# | value_loss         | 0.0242   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1999     |
# | nupdates           | 1640     |
# | policy_entropy     | 1.13     |
# | policy_loss        | -0.0224  |
# | total_timesteps    | 2650240  |
# | value_loss         | 0.0725   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1997     |
# | nupdates           | 1650     |
# | policy_entropy     | 1.16     |
# | policy_loss        | -0.0212  |
# | total_timesteps    | 2666400  |
# | value_loss         | 0.0335   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 1996     |
# | nupdates           | 1660     |
# | policy_entropy     | 1.15     |
# | policy_loss        | -0.00411 |
# | total_timesteps    | 2682560  |
# | value_loss         | 0.0264   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1996     |
# | nupdates           | 1670     |
# | policy_entropy     | 1.12     |
# | policy_loss        | -0.00574 |
# | total_timesteps    | 2698720  |
# | value_loss         | 0.034    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 1996     |
# | nupdates           | 1680     |
# | policy_entropy     | 1.12     |
# | policy_loss        | -0.0143  |
# | total_timesteps    | 2714880  |
# | value_loss         | 0.0497   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.997    |
# | fps                | 1996     |
# | nupdates           | 1690     |
# | policy_entropy     | 1.13     |
# | policy_loss        | -0.0207  |
# | total_timesteps    | 2731040  |
# | value_loss         | 0.0316   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.3917733662011333, 0.5706613216052107, 0.46541451848249416, 0.4263430671417132)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-de81e7a814f7> in <module>
#       8      'learning_rate':0.05,'learning_schedule':'constant'}
#       9 cc=OptimizeLifecycle(initargs=kw1,runargs=kw2)
# ---> 10 cc.optimize()
#
# ~/Documents/Github/lifecycle-rl/lifecycle_rl/optimizer.py in optimize(self, reset)
#      59         optimizer.maximize(
#      60             init_points=2,
# ---> 61             n_iter=20,
#      62         )
#      63
#
# /usr/local/lib/python3.7/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# /usr/local/lib/python3.7/site-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# /usr/local/lib/python3.7/site-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# ~/Documents/Github/lifecycle-rl/lifecycle_rl/optimizer.py in black_box_function(self, **x)
#      31         print(x)
#      32         self.lf.env.set_utility_params(**x)
# ---> 33         self.lf.run_results(**self.runargs)
#      34         return -self.lf.L2error()
#      35
#
# ~/Documents/Github/lifecycle-rl/lifecycle_rl/lifecycle.py in run_results(self, steps1, steps2, pop, rlmodel, twostage, save, debug, simut, results, stats, deterministic, train, predict, batch1, batch2, cont, start_from, plot, callback_minsteps, verbose, plotdebug, max_grad_norm, learning_rate, log_interval, learning_schedule)
#     778                                   cont=cont,start_from=start_from,twostage=twostage,plotdebug=plotdebug,
#     779                                   max_grad_norm=max_grad_norm,learning_rate=learning_rate,log_interval=log_interval,
# --> 780                                   learning_schedule=learning_schedule)
#     781             else:
#     782                 self.run_protocol(rlmodel=rlmodel,steps1=steps1,steps2=steps2,verbose=verbose,
#
# ~/Documents/Github/lifecycle-rl/lifecycle_rl/lifecycle.py in run_protocol(self, steps1, steps2, rlmodel, debug, batch1, batch2, cont, twostage, log_interval, start_from, save, verbose, plotdebug, max_grad_norm, learning_rate, learning_schedule)
#     815                            start_from=start_from,use_callback=False,use_vecmonitor=False,
#     816                            log_interval=log_interval,verbose=1,plotdebug=plotdebug,
# --> 817                            max_grad_norm=max_grad_norm,learning_rate=learning_rate,learning_schedule=learning_schedule)
#     818             else:
#     819                 self.train(steps=steps1,cont=False,rlmodel=rlmodel,save=tmpname,batch=batch1,debug=debug,
#
# ~/Documents/Github/lifecycle-rl/lifecycle_rl/lifecycle.py in train(self, train, debug, steps, cont, rlmodel, save, pop, batch, max_grad_norm, learning_rate, start_from, max_n_cpu, plot, use_vecmonitor, bestname, use_callback, log_interval, verbose, plotdebug, learning_schedule)
#     501             model.learn(total_timesteps=steps, callback=self.callback,log_interval=log_interval)
#     502         else:
# --> 503             model.learn(total_timesteps=steps, log_interval=log_interval)
#     504
#     505         model.save(save)
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/acktr/acktr.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     342                     obs, returns, masks, actions, values, _, states, ep_infos, true_reward = rollout
#     343                 else:
# --> 344                     rollout = self.runner.run(callback)
#     345                     obs, states, returns, masks, actions, values, ep_infos, true_reward = rollout
#     346                 # pytype:enable=bad-unpacking
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/common/runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/a2c/a2c.py in _run(self)
#     358             if isinstance(self.env.action_space, gym.spaces.Box):
#     359                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 360             obs, rewards, dones, infos = self.env.step(clipped_actions)
#     361
#     362             self.model.num_timesteps += self.n_envs
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#     148         """
#     149         self.step_async(actions)
# --> 150         return self.step_wait()
#     151
#     152     def get_images(self, *args, **kwargs) -> Sequence[np.ndarray]:
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/common/vec_env/subproc_vec_env.py in step_wait(self)
#     105
#     106     def step_wait(self):
# --> 107         results = [remote.recv() for remote in self.remotes]
#     108         self.waiting = False
#     109         obs, rews, dones, infos = zip(*results)
#
# /usr/local/lib/python3.7/site-packages/stable_baselines/common/vec_env/subproc_vec_env.py in <listcomp>(.0)
#     105
#     106     def step_wait(self):
# --> 107         results = [remote.recv() for remote in self.remotes]
#     108         self.waiting = False
#     109         obs, rews, dones, infos = zip(*results)
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
cc1=Lifecycle(env='unemployment-v2',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness,pinkslip=pinkslip,plotdebug=plotdebug)

cc1.render(load=perusresults,figname='v2_')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9fd60d75144f> in <module>
# ----> 1 cc1=Lifecycle(env='unemployment-v2',minimal=False,mortality=mortality,perustulo=False,
#       2               randomness=randomness,pinkslip=pinkslip,plotdebug=plotdebug)
#       3
#       4 cc1.render(load=perusresults,figname='v2_')
#
# NameError: name 'Lifecycle' is not defined
