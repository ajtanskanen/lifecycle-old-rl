# %% [markdown]
# # Reinforced learning, työllistyminen ja Suomen sosiaaliturva

# %% [markdown]
# Tässä tehdään laskelmat artikkelia varten. Käytössä on gym-ympäristö _unemployment-v1_ , johon on toteutettu yksityiskohtaisempi työttömyysturvamalli.

# %%
# for Colab, install fin_benefits and unemployment-gym from Github
#!pip install -q git+https://github.com/ajtanskanen/benefits.git  
#!pip install -q git+https://github.com/ajtanskanen/econogym.git
#!pip install -q git+https://github.com/ajtanskanen/lifecycle-rl.git

# and then restart kernel
  
  # For a specific version:
#!pip install tensorflow==1.15
#!pip install stable-baselines==2.8
  
# restart kernel after running pip's

# %% [markdown]
# Then load all modules.

# %%
import numpy as np
import matplotlib.pyplot as plt
from lifecycle_rl import Lifecycle

# %matplotlib inline
# %pylab inline

# varoitukset piiloon (Stable baseline ei ole vielä Tensorflow 2.0-yhteensopiva, ja Tensorflow 1.5 valittaa paljon)
import warnings
warnings.filterwarnings('ignore')

# parameters for the simulation
# episode = 51 / 205 timesteps (1y/3m timestep)
pop_size=5_000 # size of the population to be simulated
size1=5_000_000 # number of timesteps in phase 1 training (callback not used)
size2=60_000_000 # number of timesteps in phase 2 training (callback is used to save the best results)
size3=30_000_000 # number of timesteps in phase 1 training (callback not used) for policy changes
batch1=1 # size of minibatch in phase 1 as number of episodes
batch2=9_00  # size of minibatch in phase 1 as number of episodes
callback_minsteps=batch2 # how many episodes callback needs 
deterministic=True # use deterministic prediction (True) or probabilitic prediction (False)
mortality=False # include mortality in computations
randomness=True # include randomness in the state transitions (e.g., maternity leave)
rlmodel='acktr' # use ACKTR algorithm
perusmalli='best/malli_perus2'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Nykymalli
#
# Lasketaan työllisyysasteet nykymallissa.

# %%
cc1=Lifecycle(env='unemployment-v1',minimal=False,mortality=mortality,perustulo=False,
              deterministic=deterministic,randomness=randomness)
cc1.explain()
cc1.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,save=perusmalli,
                plot=True,cont=True,start_from=perusmalli,results='results/perus_results2',
                callback_minsteps=callback_minsteps,rlmodel=rlmodel,twostage=False)
cc1.render(load='results/perus_results2')
# Out:
# No mortality included
# Parameters of lifecycle:
# timestep 0.25
# gamma 0.9793703613355593 (0.9200000000000003 per anno)
# min_age 20
# max_age 70
# min_retirementage 65
# max_retirementage 70
# ansiopvraha_kesto300 None
# ansiopvraha_kesto400 None
# ansiopvraha_toe None
# perustulo False
# karenssi_kesto 0.25
# mortality False
# randomness True
# deterministic True
#
# include_putki None
# step 0.25
#
# train...
# phase 1
# acktr acktr
# batch 1 learning rate 0.25 scaled 0.25
# training...
# ---------------------------------
# | explained_variance | 0.913    |
# | fps                | 1132     |
# | nupdates           | 1        |
# | policy_entropy     | 0.563    |
# | policy_loss        | 0.902    |
# | total_timesteps    | 0        |
# | value_loss         | 2.99     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.511    |
# | fps                | 1940     |
# | nupdates           | 10       |
# | policy_entropy     | 0.587    |
# | policy_loss        | -1.75    |
# | total_timesteps    | 22041    |
# | value_loss         | 13.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.682    |
# | fps                | 1800     |
# | nupdates           | 20       |
# | policy_entropy     | 0.612    |
# | policy_loss        | 2.08     |
# | total_timesteps    | 46531    |
# | value_loss         | 15.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.762    |
# | fps                | 1651     |
# | nupdates           | 30       |
# | policy_entropy     | 0.609    |
# | policy_loss        | 1.01     |
# | total_timesteps    | 71021    |
# | value_loss         | 4.28     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.741    |
# | fps                | 1655     |
# | nupdates           | 40       |
# | policy_entropy     | 0.601    |
# | policy_loss        | -0.377   |
# | total_timesteps    | 95511    |
# | value_loss         | 2.87     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.866    |
# | fps                | 1603     |
# | nupdates           | 50       |
# | policy_entropy     | 0.624    |
# | policy_loss        | -0.679   |
# | total_timesteps    | 120001   |
# | value_loss         | 3.03     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.878    |
# | fps                | 1581     |
# | nupdates           | 60       |
# | policy_entropy     | 0.645    |
# | policy_loss        | -0.474   |
# | total_timesteps    | 144491   |
# | value_loss         | 1.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.938    |
# | fps                | 1592     |
# | nupdates           | 70       |
# | policy_entropy     | 0.611    |
# | policy_loss        | 0.362    |
# | total_timesteps    | 168981   |
# | value_loss         | 1.34     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.91     |
# | fps                | 1563     |
# | nupdates           | 80       |
# | policy_entropy     | 0.681    |
# | policy_loss        | -0.0839  |
# | total_timesteps    | 193471   |
# | value_loss         | 0.941    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 1543     |
# | nupdates           | 90       |
# | policy_entropy     | 0.616    |
# | policy_loss        | -0.0585  |
# | total_timesteps    | 217961   |
# | value_loss         | 0.448    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.903    |
# | fps                | 1553     |
# | nupdates           | 100      |
# | policy_entropy     | 0.643    |
# | policy_loss        | -0.0501  |
# | total_timesteps    | 242451   |
# | value_loss         | 0.788    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.927    |
# | fps                | 1547     |
# | nupdates           | 110      |
# | policy_entropy     | 0.639    |
# | policy_loss        | -0.0658  |
# | total_timesteps    | 266941   |
# | value_loss         | 0.865    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.924    |
# | fps                | 1537     |
# | nupdates           | 120      |
# | policy_entropy     | 0.657    |
# | policy_loss        | -0.0342  |
# | total_timesteps    | 291431   |
# | value_loss         | 0.786    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 1533     |
# | nupdates           | 130      |
# | policy_entropy     | 0.604    |
# | policy_loss        | 0.0372   |
# | total_timesteps    | 315921   |
# | value_loss         | 0.414    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 1522     |
# | nupdates           | 140      |
# | policy_entropy     | 0.648    |
# | policy_loss        | -0.11    |
# | total_timesteps    | 340411   |
# | value_loss         | 0.513    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.905    |
# | fps                | 1515     |
# | nupdates           | 150      |
# | policy_entropy     | 0.645    |
# | policy_loss        | -0.116   |
# | total_timesteps    | 364901   |
# | value_loss         | 0.961    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.917    |
# | fps                | 1508     |
# | nupdates           | 160      |
# | policy_entropy     | 0.693    |
# | policy_loss        | -0.0963  |
# | total_timesteps    | 389391   |
# | value_loss         | 0.719    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.921    |
# | fps                | 1516     |
# | nupdates           | 170      |
# | policy_entropy     | 0.658    |
# | policy_loss        | -0.0967  |
# | total_timesteps    | 413881   |
# | value_loss         | 0.617    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.923    |
# | fps                | 1511     |
# | nupdates           | 180      |
# | policy_entropy     | 0.658    |
# | policy_loss        | -0.0797  |
# | total_timesteps    | 438371   |
# | value_loss         | 0.706    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.921    |
# | fps                | 1504     |
# | nupdates           | 190      |
# | policy_entropy     | 0.669    |
# | policy_loss        | -0.166   |
# | total_timesteps    | 462861   |
# | value_loss         | 1.14     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1496     |
# | nupdates           | 200      |
# | policy_entropy     | 0.621    |
# | policy_loss        | 0.032    |
# | total_timesteps    | 487351   |
# | value_loss         | 0.427    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.935    |
# | fps                | 1501     |
# | nupdates           | 210      |
# | policy_entropy     | 0.656    |
# | policy_loss        | -0.221   |
# | total_timesteps    | 511841   |
# | value_loss         | 0.918    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.968    |
# | fps                | 1498     |
# | nupdates           | 220      |
# | policy_entropy     | 0.588    |
# | policy_loss        | -0.072   |
# | total_timesteps    | 536331   |
# | value_loss         | 0.484    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.925    |
# | fps                | 1493     |
# | nupdates           | 230      |
# | policy_entropy     | 0.615    |
# | policy_loss        | -0.0723  |
# | total_timesteps    | 560821   |
# | value_loss         | 0.6      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1490     |
# | nupdates           | 240      |
# | policy_entropy     | 0.613    |
# | policy_loss        | 0.108    |
# | total_timesteps    | 585311   |
# | value_loss         | 0.405    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.952    |
# | fps                | 1487     |
# | nupdates           | 250      |
# | policy_entropy     | 0.594    |
# | policy_loss        | -0.111   |
# | total_timesteps    | 609801   |
# | value_loss         | 0.447    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 1491     |
# | nupdates           | 260      |
# | policy_entropy     | 0.623    |
# | policy_loss        | -0.142   |
# | total_timesteps    | 634291   |
# | value_loss         | 0.883    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 1490     |
# | nupdates           | 270      |
# | policy_entropy     | 0.627    |
# | policy_loss        | -0.0715  |
# | total_timesteps    | 658781   |
# | value_loss         | 0.549    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.968    |
# | fps                | 1484     |
# | nupdates           | 280      |
# | policy_entropy     | 0.578    |
# | policy_loss        | 0.0803   |
# | total_timesteps    | 683271   |
# | value_loss         | 0.494    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.918    |
# | fps                | 1475     |
# | nupdates           | 290      |
# | policy_entropy     | 0.581    |
# | policy_loss        | -0.0654  |
# | total_timesteps    | 707761   |
# | value_loss         | 0.961    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 1481     |
# | nupdates           | 300      |
# | policy_entropy     | 0.546    |
# | policy_loss        | 0.0479   |
# | total_timesteps    | 732251   |
# | value_loss         | 0.708    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.955    |
# | fps                | 1478     |
# | nupdates           | 310      |
# | policy_entropy     | 0.587    |
# | policy_loss        | 0.135    |
# | total_timesteps    | 756741   |
# | value_loss         | 0.411    |
# ---------------------------------
# ----------------------------------
# | explained_variance | 0.979     |
# | fps                | 1476      |
# | nupdates           | 320       |
# | policy_entropy     | 0.552     |
# | policy_loss        | -0.000827 |
# | total_timesteps    | 781231    |
# | value_loss         | 0.423     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.956    |
# | fps                | 1473     |
# | nupdates           | 330      |
# | policy_entropy     | 0.624    |
# | policy_loss        | -0.137   |
# | total_timesteps    | 805721   |
# | value_loss         | 0.728    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.756    |
# | fps                | 1476     |
# | nupdates           | 340      |
# | policy_entropy     | 0.599    |
# | policy_loss        | 0.0649   |
# | total_timesteps    | 830211   |
# | value_loss         | 0.749    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.89     |
# | fps                | 1475     |
# | nupdates           | 350      |
# | policy_entropy     | 0.626    |
# | policy_loss        | -0.00262 |
# | total_timesteps    | 854701   |
# | value_loss         | 0.758    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 1473     |
# | nupdates           | 360      |
# | policy_entropy     | 0.583    |
# | policy_loss        | 0.0497   |
# | total_timesteps    | 879191   |
# | value_loss         | 0.607    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.9      |
# | fps                | 1471     |
# | nupdates           | 370      |
# | policy_entropy     | 0.646    |
# | policy_loss        | -0.139   |
# | total_timesteps    | 903681   |
# | value_loss         | 1.01     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.936    |
# | fps                | 1468     |
# | nupdates           | 380      |
# | policy_entropy     | 0.689    |
# | policy_loss        | -0.0597  |
# | total_timesteps    | 928171   |
# | value_loss         | 0.63     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.915    |
# | fps                | 1465     |
# | nupdates           | 390      |
# | policy_entropy     | 0.636    |
# | policy_loss        | -0.0451  |
# | total_timesteps    | 952661   |
# | value_loss         | 0.502    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.944    |
# | fps                | 1469     |
# | nupdates           | 400      |
# | policy_entropy     | 0.59     |
# | policy_loss        | 0.00734  |
# | total_timesteps    | 977151   |
# | value_loss         | 0.631    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 1466     |
# | nupdates           | 410      |
# | policy_entropy     | 0.603    |
# | policy_loss        | -0.0309  |
# | total_timesteps    | 1001641  |
# | value_loss         | 0.419    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 1464     |
# | nupdates           | 420      |
# | policy_entropy     | 0.603    |
# | policy_loss        | 0.0865   |
# | total_timesteps    | 1026131  |
# | value_loss         | 0.754    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.903    |
# | fps                | 1461     |
# | nupdates           | 430      |
# | policy_entropy     | 0.644    |
# | policy_loss        | -0.0258  |
# | total_timesteps    | 1050621  |
# | value_loss         | 0.76     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 1466     |
# | nupdates           | 440      |
# | policy_entropy     | 0.628    |
# | policy_loss        | -0.0421  |
# | total_timesteps    | 1075111  |
# | value_loss         | 0.508    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.933    |
# | fps                | 1463     |
# | nupdates           | 450      |
# | policy_entropy     | 0.656    |
# | policy_loss        | 0.0192   |
# | total_timesteps    | 1099601  |
# | value_loss         | 0.509    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.912    |
# | fps                | 1459     |
# | nupdates           | 460      |
# | policy_entropy     | 0.636    |
# | policy_loss        | -0.162   |
# | total_timesteps    | 1124091  |
# | value_loss         | 1.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.841    |
# | fps                | 1462     |
# | nupdates           | 470      |
# | policy_entropy     | 0.643    |
# | policy_loss        | -0.138   |
# | total_timesteps    | 1148581  |
# | value_loss         | 1.01     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 1459     |
# | nupdates           | 480      |
# | policy_entropy     | 0.618    |
# | policy_loss        | -0.0369  |
# | total_timesteps    | 1173071  |
# | value_loss         | 0.809    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.945    |
# | fps                | 1457     |
# | nupdates           | 490      |
# | policy_entropy     | 0.63     |
# | policy_loss        | 0.0258   |
# | total_timesteps    | 1197561  |
# | value_loss         | 0.559    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1455     |
# | nupdates           | 500      |
# | policy_entropy     | 0.637    |
# | policy_loss        | 0.0375   |
# | total_timesteps    | 1222051  |
# | value_loss         | 0.535    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.966    |
# | fps                | 1459     |
# | nupdates           | 510      |
# | policy_entropy     | 0.634    |
# | policy_loss        | -0.0514  |
# | total_timesteps    | 1246541  |
# | value_loss         | 0.473    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.855    |
# | fps                | 1457     |
# | nupdates           | 520      |
# | policy_entropy     | 0.734    |
# | policy_loss        | -0.257   |
# | total_timesteps    | 1271031  |
# | value_loss         | 1.74     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.942    |
# | fps                | 1454     |
# | nupdates           | 530      |
# | policy_entropy     | 0.614    |
# | policy_loss        | 0.092    |
# | total_timesteps    | 1295521  |
# | value_loss         | 0.948    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.852    |
# | fps                | 1452     |
# | nupdates           | 540      |
# | policy_entropy     | 0.619    |
# | policy_loss        | -0.0928  |
# | total_timesteps    | 1320011  |
# | value_loss         | 0.922    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.946    |
# | fps                | 1450     |
# | nupdates           | 550      |
# | policy_entropy     | 0.625    |
# | policy_loss        | 0.0247   |
# | total_timesteps    | 1344501  |
# | value_loss         | 0.589    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.915    |
# | fps                | 1450     |
# | nupdates           | 560      |
# | policy_entropy     | 0.674    |
# | policy_loss        | -0.023   |
# | total_timesteps    | 1368991  |
# | value_loss         | 0.556    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 1452     |
# | nupdates           | 570      |
# | policy_entropy     | 0.628    |
# | policy_loss        | 0.0475   |
# | total_timesteps    | 1393481  |
# | value_loss         | 0.681    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 1451     |
# | nupdates           | 580      |
# | policy_entropy     | 0.675    |
# | policy_loss        | -0.139   |
# | total_timesteps    | 1417971  |
# | value_loss         | 0.915    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.931    |
# | fps                | 1451     |
# | nupdates           | 590      |
# | policy_entropy     | 0.636    |
# | policy_loss        | -0.00803 |
# | total_timesteps    | 1442461  |
# | value_loss         | 0.848    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 1450     |
# | nupdates           | 600      |
# | policy_entropy     | 0.663    |
# | policy_loss        | 0.0448   |
# | total_timesteps    | 1466951  |
# | value_loss         | 0.831    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.945    |
# | fps                | 1449     |
# | nupdates           | 610      |
# | policy_entropy     | 0.605    |
# | policy_loss        | 0.114    |
# | total_timesteps    | 1491441  |
# | value_loss         | 0.548    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 1447     |
# | nupdates           | 620      |
# | policy_entropy     | 0.664    |
# | policy_loss        | -0.155   |
# | total_timesteps    | 1515931  |
# | value_loss         | 0.867    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 1446     |
# | nupdates           | 630      |
# | policy_entropy     | 0.601    |
# | policy_loss        | 0.00948  |
# | total_timesteps    | 1540421  |
# | value_loss         | 0.492    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.942    |
# | fps                | 1447     |
# | nupdates           | 640      |
# | policy_entropy     | 0.602    |
# | policy_loss        | -0.0107  |
# | total_timesteps    | 1564911  |
# | value_loss         | 0.509    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 1447     |
# | nupdates           | 650      |
# | policy_entropy     | 0.637    |
# | policy_loss        | 0.0396   |
# | total_timesteps    | 1589401  |
# | value_loss         | 0.371    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.921    |
# | fps                | 1443     |
# | nupdates           | 660      |
# | policy_entropy     | 0.621    |
# | policy_loss        | -0.0271  |
# | total_timesteps    | 1613891  |
# | value_loss         | 0.746    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.928    |
# | fps                | 1440     |
# | nupdates           | 670      |
# | policy_entropy     | 0.689    |
# | policy_loss        | -0.0993  |
# | total_timesteps    | 1638381  |
# | value_loss         | 0.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.958    |
# | fps                | 1437     |
# | nupdates           | 680      |
# | policy_entropy     | 0.616    |
# | policy_loss        | 0.131    |
# | total_timesteps    | 1662871  |
# | value_loss         | 0.609    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.966    |
# | fps                | 1436     |
# | nupdates           | 690      |
# | policy_entropy     | 0.659    |
# | policy_loss        | 0.0015   |
# | total_timesteps    | 1687361  |
# | value_loss         | 0.597    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 1438     |
# | nupdates           | 700      |
# | policy_entropy     | 0.617    |
# | policy_loss        | -0.0481  |
# | total_timesteps    | 1711851  |
# | value_loss         | 0.669    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.967    |
# | fps                | 1435     |
# | nupdates           | 710      |
# | policy_entropy     | 0.609    |
# | policy_loss        | 0.0279   |
# | total_timesteps    | 1736341  |
# | value_loss         | 0.398    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.939    |
# | fps                | 1434     |
# | nupdates           | 720      |
# | policy_entropy     | 0.681    |
# | policy_loss        | 0.0214   |
# | total_timesteps    | 1760831  |
# | value_loss         | 0.515    |
# ---------------------------------
# ----------------------------------
# | explained_variance | 0.973     |
# | fps                | 1433      |
# | nupdates           | 730       |
# | policy_entropy     | 0.6       |
# | policy_loss        | -0.000152 |
# | total_timesteps    | 1785321   |
# | value_loss         | 0.392     |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.926    |
# | fps                | 1435     |
# | nupdates           | 740      |
# | policy_entropy     | 0.655    |
# | policy_loss        | -0.0836  |
# | total_timesteps    | 1809811  |
# | value_loss         | 0.809    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 1434     |
# | nupdates           | 750      |
# | policy_entropy     | 0.626    |
# | policy_loss        | 0.0946   |
# | total_timesteps    | 1834301  |
# | value_loss         | 0.525    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 1432     |
# | nupdates           | 760      |
# | policy_entropy     | 0.671    |
# | policy_loss        | -0.0421  |
# | total_timesteps    | 1858791  |
# | value_loss         | 0.83     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 1431     |
# | nupdates           | 770      |
# | policy_entropy     | 0.64     |
# | policy_loss        | 0.111    |
# | total_timesteps    | 1883281  |
# | value_loss         | 0.202    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1434     |
# | nupdates           | 780      |
# | policy_entropy     | 0.608    |
# | policy_loss        | 0.0698   |
# | total_timesteps    | 1907771  |
# | value_loss         | 0.277    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1432     |
# | nupdates           | 790      |
# | policy_entropy     | 0.618    |
# | policy_loss        | 0.132    |
# | total_timesteps    | 1932261  |
# | value_loss         | 0.325    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.901    |
# | fps                | 1430     |
# | nupdates           | 800      |
# | policy_entropy     | 0.708    |
# | policy_loss        | -0.137   |
# | total_timesteps    | 1956751  |
# | value_loss         | 1.3      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.967    |
# | fps                | 1428     |
# | nupdates           | 810      |
# | policy_entropy     | 0.585    |
# | policy_loss        | 0.0224   |
# | total_timesteps    | 1981241  |
# | value_loss         | 0.393    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.902    |
# | fps                | 1424     |
# | nupdates           | 820      |
# | policy_entropy     | 0.676    |
# | policy_loss        | -0.225   |
# | total_timesteps    | 2005731  |
# | value_loss         | 1.23     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.908    |
# | fps                | 1424     |
# | nupdates           | 830      |
# | policy_entropy     | 0.602    |
# | policy_loss        | -0.0208  |
# | total_timesteps    | 2030221  |
# | value_loss         | 1.09     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 1425     |
# | nupdates           | 840      |
# | policy_entropy     | 0.673    |
# | policy_loss        | 0.0963   |
# | total_timesteps    | 2054711  |
# | value_loss         | 0.485    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 1424     |
# | nupdates           | 850      |
# | policy_entropy     | 0.665    |
# | policy_loss        | 0.0247   |
# | total_timesteps    | 2079201  |
# | value_loss         | 0.521    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.902    |
# | fps                | 1423     |
# | nupdates           | 860      |
# | policy_entropy     | 0.666    |
# | policy_loss        | -0.307   |
# | total_timesteps    | 2103691  |
# | value_loss         | 1.54     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.971    |
# | fps                | 1422     |
# | nupdates           | 870      |
# | policy_entropy     | 0.645    |
# | policy_loss        | -0.0795  |
# | total_timesteps    | 2128181  |
# | value_loss         | 0.533    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.944    |
# | fps                | 1423     |
# | nupdates           | 880      |
# | policy_entropy     | 0.646    |
# | policy_loss        | -0.219   |
# | total_timesteps    | 2152671  |
# | value_loss         | 0.765    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.944    |
# | fps                | 1423     |
# | nupdates           | 890      |
# | policy_entropy     | 0.658    |
# | policy_loss        | -0.035   |
# | total_timesteps    | 2177161  |
# | value_loss         | 0.66     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 1422     |
# | nupdates           | 900      |
# | policy_entropy     | 0.632    |
# | policy_loss        | -0.0522  |
# | total_timesteps    | 2201651  |
# | value_loss         | 0.831    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1420     |
# | nupdates           | 910      |
# | policy_entropy     | 0.601    |
# | policy_loss        | 0.197    |
# | total_timesteps    | 2226141  |
# | value_loss         | 0.421    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.928    |
# | fps                | 1420     |
# | nupdates           | 920      |
# | policy_entropy     | 0.705    |
# | policy_loss        | -0.0344  |
# | total_timesteps    | 2250631  |
# | value_loss         | 0.625    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1422     |
# | nupdates           | 930      |
# | policy_entropy     | 0.609    |
# | policy_loss        | -0.0167  |
# | total_timesteps    | 2275121  |
# | value_loss         | 0.534    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1421     |
# | nupdates           | 940      |
# | policy_entropy     | 0.642    |
# | policy_loss        | 0.0579   |
# | total_timesteps    | 2299611  |
# | value_loss         | 0.659    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.964    |
# | fps                | 1420     |
# | nupdates           | 950      |
# | policy_entropy     | 0.632    |
# | policy_loss        | -0.0299  |
# | total_timesteps    | 2324101  |
# | value_loss         | 0.465    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 1419     |
# | nupdates           | 960      |
# | policy_entropy     | 0.668    |
# | policy_loss        | -0.0968  |
# | total_timesteps    | 2348591  |
# | value_loss         | 0.517    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1418     |
# | nupdates           | 970      |
# | policy_entropy     | 0.631    |
# | policy_loss        | 0.0606   |
# | total_timesteps    | 2373081  |
# | value_loss         | 0.467    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 1419     |
# | nupdates           | 980      |
# | policy_entropy     | 0.614    |
# | policy_loss        | 0.00404  |
# | total_timesteps    | 2397571  |
# | value_loss         | 0.237    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 1420     |
# | nupdates           | 990      |
# | policy_entropy     | 0.638    |
# | policy_loss        | 0.00162  |
# | total_timesteps    | 2422061  |
# | value_loss         | 0.269    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 1419     |
# | nupdates           | 1000     |
# | policy_entropy     | 0.615    |
# | policy_loss        | 0.0929   |
# | total_timesteps    | 2446551  |
# | value_loss         | 0.663    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 1419     |
# | nupdates           | 1010     |
# | policy_entropy     | 0.676    |
# | policy_loss        | -0.107   |
# | total_timesteps    | 2471041  |
# | value_loss         | 0.638    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.928    |
# | fps                | 1418     |
# | nupdates           | 1020     |
# | policy_entropy     | 0.718    |
# | policy_loss        | -0.115   |
# | total_timesteps    | 2495531  |
# | value_loss         | 1.08     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 1417     |
# | nupdates           | 1030     |
# | policy_entropy     | 0.672    |
# | policy_loss        | 0.0258   |
# | total_timesteps    | 2520021  |
# | value_loss         | 0.436    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.946    |
# | fps                | 1416     |
# | nupdates           | 1040     |
# | policy_entropy     | 0.683    |
# | policy_loss        | 0.0104   |
# | total_timesteps    | 2544511  |
# | value_loss         | 0.466    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.93     |
# | fps                | 1415     |
# | nupdates           | 1050     |
# | policy_entropy     | 0.643    |
# | policy_loss        | -0.0298  |
# | total_timesteps    | 2569001  |
# | value_loss         | 0.699    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.935    |
# | fps                | 1417     |
# | nupdates           | 1060     |
# | policy_entropy     | 0.642    |
# | policy_loss        | 0.00177  |
# | total_timesteps    | 2593491  |
# | value_loss         | 0.589    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.949    |
# | fps                | 1416     |
# | nupdates           | 1070     |
# | policy_entropy     | 0.641    |
# | policy_loss        | 0.04     |
# | total_timesteps    | 2617981  |
# | value_loss         | 0.63     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.923    |
# | fps                | 1415     |
# | nupdates           | 1080     |
# | policy_entropy     | 0.631    |
# | policy_loss        | -0.0127  |
# | total_timesteps    | 2642471  |
# | value_loss         | 0.615    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 1415     |
# | nupdates           | 1090     |
# | policy_entropy     | 0.685    |
# | policy_loss        | 0.0181   |
# | total_timesteps    | 2666961  |
# | value_loss         | 0.308    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 1415     |
# | nupdates           | 1100     |
# | policy_entropy     | 0.621    |
# | policy_loss        | 0.116    |
# | total_timesteps    | 2691451  |
# | value_loss         | 0.698    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 1415     |
# | nupdates           | 1110     |
# | policy_entropy     | 0.643    |
# | policy_loss        | -0.0623  |
# | total_timesteps    | 2715941  |
# | value_loss         | 0.538    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1416     |
# | nupdates           | 1120     |
# | policy_entropy     | 0.676    |
# | policy_loss        | -0.011   |
# | total_timesteps    | 2740431  |
# | value_loss         | 0.399    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.913    |
# | fps                | 1416     |
# | nupdates           | 1130     |
# | policy_entropy     | 0.652    |
# | policy_loss        | -0.121   |
# | total_timesteps    | 2764921  |
# | value_loss         | 0.972    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.846    |
# | fps                | 1415     |
# | nupdates           | 1140     |
# | policy_entropy     | 0.766    |
# | policy_loss        | -0.237   |
# | total_timesteps    | 2789411  |
# | value_loss         | 1.74     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 1415     |
# | nupdates           | 1150     |
# | policy_entropy     | 0.586    |
# | policy_loss        | 0.195    |
# | total_timesteps    | 2813901  |
# | value_loss         | 0.562    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1414     |
# | nupdates           | 1160     |
# | policy_entropy     | 0.631    |
# | policy_loss        | 0.0377   |
# | total_timesteps    | 2838391  |
# | value_loss         | 0.545    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.912    |
# | fps                | 1416     |
# | nupdates           | 1170     |
# | policy_entropy     | 0.605    |
# | policy_loss        | -0.0253  |
# | total_timesteps    | 2862881  |
# | value_loss         | 0.595    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.93     |
# | fps                | 1416     |
# | nupdates           | 1180     |
# | policy_entropy     | 0.683    |
# | policy_loss        | -0.17    |
# | total_timesteps    | 2887371  |
# | value_loss         | 1.07     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 1415     |
# | nupdates           | 1190     |
# | policy_entropy     | 0.644    |
# | policy_loss        | -0.122   |
# | total_timesteps    | 2911861  |
# | value_loss         | 0.912    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.949    |
# | fps                | 1416     |
# | nupdates           | 1200     |
# | policy_entropy     | 0.645    |
# | policy_loss        | -0.171   |
# | total_timesteps    | 2936351  |
# | value_loss         | 0.8      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.874    |
# | fps                | 1416     |
# | nupdates           | 1210     |
# | policy_entropy     | 0.639    |
# | policy_loss        | 0.0253   |
# | total_timesteps    | 2960841  |
# | value_loss         | 0.95     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.95     |
# | fps                | 1416     |
# | nupdates           | 1220     |
# | policy_entropy     | 0.632    |
# | policy_loss        | -0.0145  |
# | total_timesteps    | 2985331  |
# | value_loss         | 0.57     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 1415     |
# | nupdates           | 1230     |
# | policy_entropy     | 0.652    |
# | policy_loss        | -0.157   |
# | total_timesteps    | 3009821  |
# | value_loss         | 0.721    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.937    |
# | fps                | 1417     |
# | nupdates           | 1240     |
# | policy_entropy     | 0.688    |
# | policy_loss        | 0.0561   |
# | total_timesteps    | 3034311  |
# | value_loss         | 0.625    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1416     |
# | nupdates           | 1250     |
# | policy_entropy     | 0.668    |
# | policy_loss        | -0.00879 |
# | total_timesteps    | 3058801  |
# | value_loss         | 0.417    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.899    |
# | fps                | 1415     |
# | nupdates           | 1260     |
# | policy_entropy     | 0.743    |
# | policy_loss        | -0.154   |
# | total_timesteps    | 3083291  |
# | value_loss         | 1.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 1416     |
# | nupdates           | 1270     |
# | policy_entropy     | 0.622    |
# | policy_loss        | 0.0299   |
# | total_timesteps    | 3107781  |
# | value_loss         | 0.401    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 1416     |
# | nupdates           | 1280     |
# | policy_entropy     | 0.58     |
# | policy_loss        | 0.131    |
# | total_timesteps    | 3132271  |
# | value_loss         | 0.361    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 1416     |
# | nupdates           | 1290     |
# | policy_entropy     | 0.634    |
# | policy_loss        | -0.115   |
# | total_timesteps    | 3156761  |
# | value_loss         | 0.513    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.936    |
# | fps                | 1416     |
# | nupdates           | 1300     |
# | policy_entropy     | 0.658    |
# | policy_loss        | 0.0512   |
# | total_timesteps    | 3181251  |
# | value_loss         | 0.566    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.905    |
# | fps                | 1416     |
# | nupdates           | 1310     |
# | policy_entropy     | 0.647    |
# | policy_loss        | -0.0722  |
# | total_timesteps    | 3205741  |
# | value_loss         | 0.643    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.919    |
# | fps                | 1415     |
# | nupdates           | 1320     |
# | policy_entropy     | 0.661    |
# | policy_loss        | -0.0733  |
# | total_timesteps    | 3230231  |
# | value_loss         | 0.825    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 1416     |
# | nupdates           | 1330     |
# | policy_entropy     | 0.63     |
# | policy_loss        | 0.109    |
# | total_timesteps    | 3254721  |
# | value_loss         | 0.32     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.946    |
# | fps                | 1415     |
# | nupdates           | 1340     |
# | policy_entropy     | 0.635    |
# | policy_loss        | -0.103   |
# | total_timesteps    | 3279211  |
# | value_loss         | 0.507    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.966    |
# | fps                | 1415     |
# | nupdates           | 1350     |
# | policy_entropy     | 0.588    |
# | policy_loss        | 0.0692   |
# | total_timesteps    | 3303701  |
# | value_loss         | 0.391    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 1414     |
# | nupdates           | 1360     |
# | policy_entropy     | 0.652    |
# | policy_loss        | 0.0751   |
# | total_timesteps    | 3328191  |
# | value_loss         | 0.399    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.919    |
# | fps                | 1414     |
# | nupdates           | 1370     |
# | policy_entropy     | 0.7      |
# | policy_loss        | -0.0985  |
# | total_timesteps    | 3352681  |
# | value_loss         | 0.875    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.962    |
# | fps                | 1416     |
# | nupdates           | 1380     |
# | policy_entropy     | 0.651    |
# | policy_loss        | -0.0196  |
# | total_timesteps    | 3377171  |
# | value_loss         | 0.503    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.927    |
# | fps                | 1415     |
# | nupdates           | 1390     |
# | policy_entropy     | 0.758    |
# | policy_loss        | -0.153   |
# | total_timesteps    | 3401661  |
# | value_loss         | 1.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 1414     |
# | nupdates           | 1400     |
# | policy_entropy     | 0.581    |
# | policy_loss        | -0.0414  |
# | total_timesteps    | 3426151  |
# | value_loss         | 0.763    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 1414     |
# | nupdates           | 1410     |
# | policy_entropy     | 0.686    |
# | policy_loss        | -0.0258  |
# | total_timesteps    | 3450641  |
# | value_loss         | 0.562    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.945    |
# | fps                | 1415     |
# | nupdates           | 1420     |
# | policy_entropy     | 0.584    |
# | policy_loss        | 0.0451   |
# | total_timesteps    | 3475131  |
# | value_loss         | 0.387    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 1415     |
# | nupdates           | 1430     |
# | policy_entropy     | 0.589    |
# | policy_loss        | 0.0233   |
# | total_timesteps    | 3499621  |
# | value_loss         | 0.501    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 1414     |
# | nupdates           | 1440     |
# | policy_entropy     | 0.616    |
# | policy_loss        | 0.0162   |
# | total_timesteps    | 3524111  |
# | value_loss         | 0.691    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 1415     |
# | nupdates           | 1450     |
# | policy_entropy     | 0.638    |
# | policy_loss        | -0.0318  |
# | total_timesteps    | 3548601  |
# | value_loss         | 0.569    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1416     |
# | nupdates           | 1460     |
# | policy_entropy     | 0.624    |
# | policy_loss        | 0.0297   |
# | total_timesteps    | 3573091  |
# | value_loss         | 0.352    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.955    |
# | fps                | 1415     |
# | nupdates           | 1470     |
# | policy_entropy     | 0.636    |
# | policy_loss        | 0.0705   |
# | total_timesteps    | 3597581  |
# | value_loss         | 0.553    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 1415     |
# | nupdates           | 1480     |
# | policy_entropy     | 0.642    |
# | policy_loss        | 0.0418   |
# | total_timesteps    | 3622071  |
# | value_loss         | 0.6      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.949    |
# | fps                | 1415     |
# | nupdates           | 1490     |
# | policy_entropy     | 0.659    |
# | policy_loss        | 0.000407 |
# | total_timesteps    | 3646561  |
# | value_loss         | 0.648    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.968    |
# | fps                | 1413     |
# | nupdates           | 1500     |
# | policy_entropy     | 0.66     |
# | policy_loss        | 0.0337   |
# | total_timesteps    | 3671051  |
# | value_loss         | 0.508    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 1412     |
# | nupdates           | 1510     |
# | policy_entropy     | 0.741    |
# | policy_loss        | -0.0882  |
# | total_timesteps    | 3695541  |
# | value_loss         | 0.478    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.959    |
# | fps                | 1414     |
# | nupdates           | 1520     |
# | policy_entropy     | 0.655    |
# | policy_loss        | 0.0321   |
# | total_timesteps    | 3720031  |
# | value_loss         | 0.586    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.973    |
# | fps                | 1413     |
# | nupdates           | 1530     |
# | policy_entropy     | 0.635    |
# | policy_loss        | 0.0933   |
# | total_timesteps    | 3744521  |
# | value_loss         | 0.327    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 1413     |
# | nupdates           | 1540     |
# | policy_entropy     | 0.659    |
# | policy_loss        | 0.0387   |
# | total_timesteps    | 3769011  |
# | value_loss         | 0.699    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.896    |
# | fps                | 1412     |
# | nupdates           | 1550     |
# | policy_entropy     | 0.656    |
# | policy_loss        | -0.0453  |
# | total_timesteps    | 3793501  |
# | value_loss         | 0.87     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.943    |
# | fps                | 1411     |
# | nupdates           | 1560     |
# | policy_entropy     | 0.709    |
# | policy_loss        | -0.022   |
# | total_timesteps    | 3817991  |
# | value_loss         | 0.667    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.941    |
# | fps                | 1411     |
# | nupdates           | 1570     |
# | policy_entropy     | 0.647    |
# | policy_loss        | -0.0548  |
# | total_timesteps    | 3842481  |
# | value_loss         | 0.703    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1411     |
# | nupdates           | 1580     |
# | policy_entropy     | 0.573    |
# | policy_loss        | 0.0344   |
# | total_timesteps    | 3866971  |
# | value_loss         | 0.264    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.934    |
# | fps                | 1411     |
# | nupdates           | 1590     |
# | policy_entropy     | 0.636    |
# | policy_loss        | -0.0825  |
# | total_timesteps    | 3891461  |
# | value_loss         | 0.739    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.919    |
# | fps                | 1411     |
# | nupdates           | 1600     |
# | policy_entropy     | 0.696    |
# | policy_loss        | -0.17    |
# | total_timesteps    | 3915951  |
# | value_loss         | 0.674    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.909    |
# | fps                | 1411     |
# | nupdates           | 1610     |
# | policy_entropy     | 0.652    |
# | policy_loss        | -0.192   |
# | total_timesteps    | 3940441  |
# | value_loss         | 0.811    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.966    |
# | fps                | 1410     |
# | nupdates           | 1620     |
# | policy_entropy     | 0.705    |
# | policy_loss        | -0.0139  |
# | total_timesteps    | 3964931  |
# | value_loss         | 0.432    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 1409     |
# | nupdates           | 1630     |
# | policy_entropy     | 0.762    |
# | policy_loss        | -0.0685  |
# | total_timesteps    | 3989421  |
# | value_loss         | 0.557    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.864    |
# | fps                | 1408     |
# | nupdates           | 1640     |
# | policy_entropy     | 0.71     |
# | policy_loss        | -0.263   |
# | total_timesteps    | 4013911  |
# | value_loss         | 1.44     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.944    |
# | fps                | 1408     |
# | nupdates           | 1650     |
# | policy_entropy     | 0.659    |
# | policy_loss        | -0.105   |
# | total_timesteps    | 4038401  |
# | value_loss         | 0.787    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 1408     |
# | nupdates           | 1660     |
# | policy_entropy     | 0.67     |
# | policy_loss        | 0.129    |
# | total_timesteps    | 4062891  |
# | value_loss         | 0.644    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.907    |
# | fps                | 1408     |
# | nupdates           | 1670     |
# | policy_entropy     | 0.676    |
# | policy_loss        | -0.0801  |
# | total_timesteps    | 4087381  |
# | value_loss         | 0.923    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.969    |
# | fps                | 1407     |
# | nupdates           | 1680     |
# | policy_entropy     | 0.593    |
# | policy_loss        | 0.0254   |
# | total_timesteps    | 4111871  |
# | value_loss         | 0.615    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 1407     |
# | nupdates           | 1690     |
# | policy_entropy     | 0.671    |
# | policy_loss        | -0.17    |
# | total_timesteps    | 4136361  |
# | value_loss         | 0.869    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.911    |
# | fps                | 1406     |
# | nupdates           | 1700     |
# | policy_entropy     | 0.664    |
# | policy_loss        | -0.0556  |
# | total_timesteps    | 4160851  |
# | value_loss         | 0.508    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 1405     |
# | nupdates           | 1710     |
# | policy_entropy     | 0.646    |
# | policy_loss        | 0.0223   |
# | total_timesteps    | 4185341  |
# | value_loss         | 0.554    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 1404     |
# | nupdates           | 1720     |
# | policy_entropy     | 0.673    |
# | policy_loss        | 0.0353   |
# | total_timesteps    | 4209831  |
# | value_loss         | 0.54     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.936    |
# | fps                | 1404     |
# | nupdates           | 1730     |
# | policy_entropy     | 0.65     |
# | policy_loss        | -0.175   |
# | total_timesteps    | 4234321  |
# | value_loss         | 0.755    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.925    |
# | fps                | 1402     |
# | nupdates           | 1740     |
# | policy_entropy     | 0.648    |
# | policy_loss        | -0.00377 |
# | total_timesteps    | 4258811  |
# | value_loss         | 0.879    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.933    |
# | fps                | 1400     |
# | nupdates           | 1750     |
# | policy_entropy     | 0.667    |
# | policy_loss        | -0.159   |
# | total_timesteps    | 4283301  |
# | value_loss         | 0.78     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 1399     |
# | nupdates           | 1760     |
# | policy_entropy     | 0.662    |
# | policy_loss        | -0.0093  |
# | total_timesteps    | 4307791  |
# | value_loss         | 0.653    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.837    |
# | fps                | 1398     |
# | nupdates           | 1770     |
# | policy_entropy     | 0.633    |
# | policy_loss        | -0.0692  |
# | total_timesteps    | 4332281  |
# | value_loss         | 1.24     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.954    |
# | fps                | 1398     |
# | nupdates           | 1780     |
# | policy_entropy     | 0.572    |
# | policy_loss        | 0.00555  |
# | total_timesteps    | 4356771  |
# | value_loss         | 0.636    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.957    |
# | fps                | 1398     |
# | nupdates           | 1790     |
# | policy_entropy     | 0.632    |
# | policy_loss        | -0.00497 |
# | total_timesteps    | 4381261  |
# | value_loss         | 0.555    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.966    |
# | fps                | 1397     |
# | nupdates           | 1800     |
# | policy_entropy     | 0.659    |
# | policy_loss        | 0.0403   |
# | total_timesteps    | 4405751  |
# | value_loss         | 0.426    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.942    |
# | fps                | 1396     |
# | nupdates           | 1810     |
# | policy_entropy     | 0.65     |
# | policy_loss        | -0.107   |
# | total_timesteps    | 4430241  |
# | value_loss         | 0.75     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.936    |
# | fps                | 1395     |
# | nupdates           | 1820     |
# | policy_entropy     | 0.604    |
# | policy_loss        | 0.0881   |
# | total_timesteps    | 4454731  |
# | value_loss         | 0.531    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.932    |
# | fps                | 1394     |
# | nupdates           | 1830     |
# | policy_entropy     | 0.593    |
# | policy_loss        | 0.0953   |
# | total_timesteps    | 4479221  |
# | value_loss         | 0.713    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 1394     |
# | nupdates           | 1840     |
# | policy_entropy     | 0.568    |
# | policy_loss        | 0.0815   |
# | total_timesteps    | 4503711  |
# | value_loss         | 0.49     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.958    |
# | fps                | 1394     |
# | nupdates           | 1850     |
# | policy_entropy     | 0.611    |
# | policy_loss        | 0.00303  |
# | total_timesteps    | 4528201  |
# | value_loss         | 0.517    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.915    |
# | fps                | 1394     |
# | nupdates           | 1860     |
# | policy_entropy     | 0.631    |
# | policy_loss        | -0.00739 |
# | total_timesteps    | 4552691  |
# | value_loss         | 0.54     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.907    |
# | fps                | 1393     |
# | nupdates           | 1870     |
# | policy_entropy     | 0.676    |
# | policy_loss        | -0.119   |
# | total_timesteps    | 4577181  |
# | value_loss         | 0.956    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.965    |
# | fps                | 1392     |
# | nupdates           | 1880     |
# | policy_entropy     | 0.589    |
# | policy_loss        | 0.0354   |
# | total_timesteps    | 4601671  |
# | value_loss         | 0.624    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.922    |
# | fps                | 1392     |
# | nupdates           | 1890     |
# | policy_entropy     | 0.593    |
# | policy_loss        | 0.14     |
# | total_timesteps    | 4626161  |
# | value_loss         | 0.38     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.958    |
# | fps                | 1391     |
# | nupdates           | 1900     |
# | policy_entropy     | 0.62     |
# | policy_loss        | 0.0966   |
# | total_timesteps    | 4650651  |
# | value_loss         | 0.561    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.955    |
# | fps                | 1391     |
# | nupdates           | 1910     |
# | policy_entropy     | 0.582    |
# | policy_loss        | 0.0655   |
# | total_timesteps    | 4675141  |
# | value_loss         | 0.499    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.947    |
# | fps                | 1390     |
# | nupdates           | 1920     |
# | policy_entropy     | 0.668    |
# | policy_loss        | 0.0492   |
# | total_timesteps    | 4699631  |
# | value_loss         | 0.526    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.907    |
# | fps                | 1388     |
# | nupdates           | 1930     |
# | policy_entropy     | 0.653    |
# | policy_loss        | -0.144   |
# | total_timesteps    | 4724121  |
# | value_loss         | 0.624    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 1389     |
# | nupdates           | 1940     |
# | policy_entropy     | 0.577    |
# | policy_loss        | 0.0582   |
# | total_timesteps    | 4748611  |
# | value_loss         | 0.31     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.93     |
# | fps                | 1389     |
# | nupdates           | 1950     |
# | policy_entropy     | 0.646    |
# | policy_loss        | -0.11    |
# | total_timesteps    | 4773101  |
# | value_loss         | 0.513    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.906    |
# | fps                | 1389     |
# | nupdates           | 1960     |
# | policy_entropy     | 0.732    |
# | policy_loss        | -0.19    |
# | total_timesteps    | 4797591  |
# | value_loss         | 1.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.94     |
# | fps                | 1388     |
# | nupdates           | 1970     |
# | policy_entropy     | 0.705    |
# | policy_loss        | -0.0363  |
# | total_timesteps    | 4822081  |
# | value_loss         | 0.58     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.875    |
# | fps                | 1387     |
# | nupdates           | 1980     |
# | policy_entropy     | 0.694    |
# | policy_loss        | -0.0344  |
# | total_timesteps    | 4846571  |
# | value_loss         | 0.947    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.928    |
# | fps                | 1386     |
# | nupdates           | 1990     |
# | policy_entropy     | 0.664    |
# | policy_loss        | -0.032   |
# | total_timesteps    | 4871061  |
# | value_loss         | 0.749    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.9      |
# | fps                | 1386     |
# | nupdates           | 2000     |
# | policy_entropy     | 0.665    |
# | policy_loss        | -0.0982  |
# | total_timesteps    | 4895551  |
# | value_loss         | 0.945    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.952    |
# | fps                | 1386     |
# | nupdates           | 2010     |
# | policy_entropy     | 0.632    |
# | policy_loss        | 0.00559  |
# | total_timesteps    | 4920041  |
# | value_loss         | 0.675    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.975    |
# | fps                | 1386     |
# | nupdates           | 2020     |
# | policy_entropy     | 0.635    |
# | policy_loss        | 0.107    |
# | total_timesteps    | 4944531  |
# | value_loss         | 0.412    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 1386     |
# | nupdates           | 2030     |
# | policy_entropy     | 0.614    |
# | policy_loss        | 0.146    |
# | total_timesteps    | 4969021  |
# | value_loss         | 0.503    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.972    |
# | fps                | 1385     |
# | nupdates           | 2040     |
# | policy_entropy     | 0.666    |
# | policy_loss        | 0.00649  |
# | total_timesteps    | 4993511  |
# | value_loss         | 0.417    |
# ---------------------------------
# done
# predict...
# simulating  best/malli_perus2
# predicting...
# HBox(children=(IntProgress(value=0, description='Population', max=5000, style=ProgressStyle(description_width=…
# No handles with labels found to put in legend.
# Yhteensä reward 242.68131072516312

# %%
#%tensorboard --logdir tmp/tenb

# %% [markdown]
# # Porrastettu työttömyysturva

# %%
cc2_porras=Lifecycle(env='unemploymentSteps-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness)
cc2_porras.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_steps',plot=True,
                results='results/steps_results',start_from=perusmalli,cont=True,
                callback_minsteps=callback_minsteps)
cc2_porras.render(load='results/steps_results')

# %%
cc2_porras.compare_with(cc1)

# %% [markdown]
# # Työttömyysputken poisto
#
# Työttömyysputki on suosittu elinkaarimalleissa. Tarkastellaan millainen työllisyysvaikutus on putken poistamisella.

# %%
cc1_putki=Lifecycle(env='unemployment-v1',minimal=False,include_putki=False,mortality=mortality,
                    perustulo=False,randomness=randomness)
cc1_putki.run_results(debug=False,steps1=size1,steps2=size2,pop=pop_size,deterministic=deterministic,
                      train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_putki',
                      plot=True,results='results/putki_results',start_from=perusmalli,cont=True,
                      callback_minsteps=callback_minsteps)
cc1_putki.render(load='results/putki_results')
cc1_putki.compare_with(cc1)

# %%
cc1_putki.render(load='results/putki_results')
cc1_putki.compare_with(cc1)

# %% [markdown]
# # EK:n malli
#
# Lasketaan vertailukelpoiset työllisyysasteet EK:n ehdottamalla mallilla. Mallissa on toteuttu muutoksia ansiosidonnaiseen työttömyysturvaan, asumistukeen, toimeentulotukeen ja verotukseen.

# %%
cc2=Lifecycle(env='unemploymentEK-v1',minimal=False,mortality=mortality,perustulo=False,
              randomness=randomness)
cc2.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_ek',plot=True,
                results='results/ek_results',start_from='best/malli_perus',cont=True,
                callback_minsteps=callback_minsteps)
cc2.render(load='results/ek_results')
cc2.load_sim(load='results/ek_results')

# %%
cc2.compare_with(cc1)
#print(cc1.episodestats.empstate/cc1.n_pop,cc2.episodestats.empstate/cc2.n_pop)
#cc2.episodestats.load_sim('results/ek_res__best')
#cc2.episodestats.render()

# %% [markdown]
# # Verifiointi
#
# Ajetaan sama simulaatio kaksi kertaa ja tarkastetaan että tulokset ovat sama. Tässä ideana on varmistaa, että satunnaisuus ei sotke tulosten arviointia.

# %% [markdown]
# # Työssäoloehdon pituus 12 kk
#
# Entä jos työssäoloehto olisikin 12 kuukautta pitkä nykyisen 6 kuukauden sijaan?

# %%
cc1_toe=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_toe=1.0,mortality=mortality,
                  perustulo=False,randomness=randomness)
cc1_toe.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=False,predict=True,batch1=batch1,batch2=batch2,save='best/best_12kk',plot=True,
                    results='results/12kk_results',start_from=perusmalli,cont=True,
                callback_minsteps=callback_minsteps)
cc1_toe.render(load='results/12kk_results')
cc1_toe.compare_with(cc1)

# %% [markdown]
# # Ansiosidonnaisen päivärahan lyhennys 50 pv
#
# Tarkastellaan, miten työllisyyteen vaikuttaisi ansiosidonnaisen päivärahan lyhentäminen 50 päivällä. Tällöin alle kolmen vuoden työhistorialla ansiosidonnaisen päivärahan enimmäiskesto olisi 250 pv ja pidemmällä työhistorialla enimmäiskesto olisi 350 pv.

# %%
cc1_350=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=250,ansiopvraha_kesto400=350,
                  mortality=mortality,perustulo=False,randomness=randomness)
cc1_350.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=False,predict=True,batch1=batch1,batch2=batch2,save='best/malli_50pv',plot=True,
                    results='results/50pv_results',start_from=perusmalli,cont=True,
                    callback_minsteps=callback_minsteps)
cc1_350.render(load='results/50pv_results')
cc1_350.compare_with(cc1)

# %% [markdown]
# # Perustulo

# %%
cc1_pt=Lifecycle(env='unemployment-v1',minimal=False,perustulo=True,mortality=mortality,
                 randomness=randomness)
cc1_pt.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                   train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_pt',plot=True,
                   results='results/perustulo_results',start_from=perusmalli,cont=True,
                callback_minsteps=callback_minsteps)
cc1_pt.render(load='results/perustulo_results')
cc1_pt.compare_with(cc1)

# %% [markdown]
# # 300 vs 400 päivän kesto ansiosidonnaisessa
#
# Mikä on alle kolmen vuoden työhistorian lyhyemmän (300 pv) ansiosidonnaisen päivärahan enimmäiskeston vaikutus työllisyyteen? Kokeillaan miten työllisyyteen vaikuttaisi sen pidentäminen 400 päivään.

# %%
cc1_400=Lifecycle(env='unemployment-v1',minimal=False,ansiopvraha_kesto300=400,mortality=mortality,
                  perustulo=False,randomness=randomness)
cc1_400.run_results(debug=False,steps1=size3,steps2=size2,pop=pop_size,deterministic=deterministic,
                    train=True,predict=True,batch1=batch1,batch2=batch2,save='best/malli_300pv',plot=True,
                    results='results/300pv_results',start_from=perusmalli,cont=True,
                callback_minsteps=callback_minsteps)
cc1_400.render(load='results/300pv_results')
cc1_400.compare_with(cc1)
